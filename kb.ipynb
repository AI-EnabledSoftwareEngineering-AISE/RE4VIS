# %%
import spacy
import spacy_component

nlp = spacy.load("en_core_web_sm")

nlp.add_pipe("rebel", after="senter", config={
    'device':0, # Number of the GPU, -1 if want to use CPU
    'model_name':'Babelscape/rebel-large'} # Model used, will default to 'Babelscape/rebel-large' if not given
    )

# %%
import pickle

def save_kb(kb, filename):
    with open(filename, "wb") as f:
        pickle.dump(kb, f)

def load_kb(filename):
    res = None
    with open(filename, "rb") as f:
        res = pickle.load(f)
    return res

# %%
def divide_chunks(l, n):
     
    # looping till length l
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %%
def get_length(fn):
    ln = 0
    with open(fn, "r") as rf:
        r_text = rf.readlines()
        ln = len(r_text)
    return ln

# %%
# knowledge base class
class KB():
    def __init__(self):
        self.relations = []

    def are_relations_equal(self, r1, r2):
        return all(r1[attr] == r2[attr] for attr in ["head_span", "relation", "tail_span"])

    def exists_relation(self, r1):
        return any(self.are_relations_equal(r1, r2) for r2 in self.relations)

    def add_relation(self, r):
        if not self.exists_relation(r):
            self.relations.append(r)

    def print(self):
        print("Relations:")
        for r in self.relations:
            print(f"  {r}")

# %%
! ls ../../text_processing/data/wiki_texts/ped_pt | wc -l
# Out:
# 13615

# %%
data_path = "/home/xtest/projects/text_processing/data/"

# %%
import glob

# %%
file_names_wi_p = [f for f in glob.glob(f"{data_path}/wiki_texts/ped_pt/*.txt")]
print(len(file_names_wi_p))
# Out:
# 13615

# %%
new_br = [f for f in glob.glob(f"{data_path}/britanica_texts/ped_pt/*.txt") if get_length(f) < 30000]
len(new_br)
# Out:
# 992

# %%
x = list(divide_chunks(file_names_wi_p, 4600))
print(len(x))
print(len(x[0]))
# Out:
# 3
# 4600

# %%
extracted_files = []

# %%
search_files = list(set(x[0]) - set(extracted_files))
len(search_files)
# Out:
# 4600

# %%
from tqdm.notebook import tqdm

# %%
kb = KB()

# %%
count = 0
for fn in tqdm(search_files):
    count += 1
#     print(f"Processing file {count} of {len(search_files)}")
    with open(fn, 'r') as f:
        lines = [line for line in f.readlines() if line.strip()]
    for l in lines:
        doc = nlp(l)
        doc_list = nlp.pipe([l])
        for value, rel_dict in doc._.rel.items():
            # print(f"{value}: {rel_dict}")
            kb.add_relation(rel_dict)
    extracted_files.append(fn)
# Out:
#   0%|          | 0/4600 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
count
# Out:
# 4600

# %%
! pwd
# Out:
# /home/xtest/projects/KnowledgeGraph/rebel

# %%
kb.relations[0]['relation']
# Out:
# 'located in the administrative territorial entity'

# %%
new_rel_list = [
    {
        'relation': str(item['relation']),  # Keep the 'relation' unchanged
        'head': str(item['head_span']),     # Change 'head_span' key to 'head'
        'tail': str(item['tail_span'])      # Change 'tail_span' key to 'tail'
    }
    for item in kb.relations
]

# %%
new_rel_list
# Out:
# [{'relation': 'located in the administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'East of England'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'East of England',
#   'tail': 'Essex'},
#  {'relation': 'shares border with',
#   'head': 'Suffolk',
#   'tail': 'Cambridgeshire'},
#  {'relation': 'shares border with',
#   'head': 'Suffolk',
#   'tail': 'Greater London'},
#  {'relation': 'shares border with',
#   'head': 'Cambridgeshire',
#   'tail': 'Suffolk'},
#  {'relation': 'shares border with',
#   'head': 'Cambridgeshire',
#   'tail': 'Hertfordshire'},
#  {'relation': 'shares border with',
#   'head': 'Hertfordshire',
#   'tail': 'Cambridgeshire'},
#  {'relation': 'shares border with', 'head': 'Hertfordshire', 'tail': 'Kent'},
#  {'relation': 'shares border with', 'head': 'Kent', 'tail': 'Hertfordshire'},
#  {'relation': 'located in or next to body of water',
#   'head': 'Kent',
#   'tail': 'River Thames'},
#  {'relation': 'shares border with', 'head': 'Kent', 'tail': 'Greater London'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'River Thames',
#   'tail': 'Kent'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Colchester',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Chelmsford',
#   'tail': 'Essex'},
#  {'relation': 'instance of',
#   'head': 'East of England',
#   'tail': 'region.[3][4'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'ancient county',
#   'tail': 'Essex'},
#  {'relation': 'legislative body',
#   'head': 'administrative county',
#   'tail': 'County Council'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'County Council',
#   'tail': 'administrative county'},
#  {'relation': 'instance of',
#   'head': 'Thurrock',
#   'tail': 'unitary authorities'},
#  {'relation': 'instance of',
#   'head': 'Southend-on-Sea',
#   'tail': 'unitary authorities'},
#  {'relation': 'part of', 'head': 'Kingdom of Essex', 'tail': 'Anglo-Saxon'},
#  {'relation': 'opposite of', 'head': 'rural areas', 'tail': 'urban areas'},
#  {'relation': 'opposite of', 'head': 'urban areas', 'tail': 'rural areas'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'home counties',
#   'tail': 'England'},
#  {'relation': 'instance of', 'head': 'Essex', 'tail': 'ceremonial county'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Kent'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Greater London'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Hertfordshire'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Cambridgeshire'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Suffolk'},
#  {'relation': 'shares border with', 'head': 'Kent', 'tail': 'Essex'},
#  {'relation': 'shares border with', 'head': 'Kent', 'tail': 'Greater London'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Thames Estuary',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Thames Estuary',
#   'tail': 'Kent'},
#  {'relation': 'shares border with', 'head': 'Greater London', 'tail': 'Essex'},
#  {'relation': 'shares border with', 'head': 'Greater London', 'tail': 'Kent'},
#  {'relation': 'shares border with',
#   'head': 'Greater London',
#   'tail': 'Hertfordshire'},
#  {'relation': 'subclass of', 'head': 'ancient', 'tail': 'county of Essex'},
#  {'relation': 'subclass of', 'head': 'ceremonial', 'tail': 'county of Essex'},
#  {'relation': 'subclass of',
#   'head': 'administrative',
#   'tail': 'county of Essex'},
#  {'relation': 'subclass of',
#   'head': 'postal counties',
#   'tail': 'county of Essex'},
#  {'relation': 'instance of', 'head': 'Essex', 'tail': 'ancient county'},
#  {'relation': 'shares border with',
#   'head': 'Cambridgeshire',
#   'tail': 'Greater London'},
#  {'relation': 'shares border with',
#   'head': 'Greater London',
#   'tail': 'Cambridgeshire'},
#  {'relation': 'inception', 'head': 'Thurrock', 'tail': '1998'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'Lord Lieutenant of Essex',
#   'tail': 'ceremonial county'},
#  {'relation': 'inception', 'head': 'Thurrock', 'tail': '1998'},
#  {'relation': 'inception', 'head': 'Southend', 'tail': '1998'},
#  {'relation': 'instance of',
#   'head': 'Essex County Council',
#   'tail': 'administrative county'},
#  {'relation': 'shares border with',
#   'head': 'Greater London',
#   'tail': 'Thurrock'},
#  {'relation': 'industry', 'head': 'Royal Mail', 'tail': 'sorting of mail'},
#  {'relation': 'instance of', 'head': 'Ancient', 'tail': 'postal county'},
#  {'relation': 'instance of',
#   'head': 'Ceremonial County',
#   'tail': 'postal county'},
#  {'relation': 'shares border with', 'head': 'Hertfordshire', 'tail': 'Essex'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Hertfordshire'},
#  {'relation': 'dissolved, abolished or demolished date',
#   'head': 'Postal counties',
#   'tail': '1996'},
#  {'relation': 'shares border with',
#   'head': 'Essex',
#   'tail': 'Greater London east of the Lea'},
#  {'relation': 'shares border with',
#   'head': 'Greater London east of the Lea',
#   'tail': 'Essex'},
#  {'relation': 'publication date',
#   'head': 'London Government Act 1963',
#   'tail': '1963'},
#  {'relation': 'instance of',
#   'head': 'Greater London',
#   'tail': 'ceremonial county'},
#  {'relation': 'replaces',
#   'head': 'Greater London',
#   'tail': 'County of London'},
#  {'relation': 'replaced by',
#   'head': 'County of London',
#   'tail': 'Greater London'},
#  {'relation': 'instance of',
#   'head': 'County of London',
#   'tail': 'ceremonial county'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Metropolitan Essex',
#   'tail': 'Essex'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'Metropolitan Essex'},
#  {'relation': 'located in or next to body of water',
#   'head': 'Essex',
#   'tail': 'North Sea'},
#  {'relation': 'different from',
#   'head': 'estuaries',
#   'tail': 'river estuaries'},
#  {'relation': 'different from',
#   'head': 'river estuaries',
#   'tail': 'estuaries'},
#  {'relation': 'highest point', 'head': 'Essex', 'tail': 'Chrishall Common'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Hertfordshire'},
#  {'relation': 'shares border with', 'head': 'Hertfordshire', 'tail': 'Essex'},
#  {'relation': 'facet of', 'head': 'physical geography', 'tail': 'London'},
#  {'relation': 'location', 'head': 'economy', 'tail': 'Essex'},
#  {'relation': 'subclass of', 'head': 'by rail', 'tail': 'commuting'},
#  {'relation': 'subclass of', 'head': 'by road', 'tail': 'commuting'},
#  {'relation': 'capital', 'head': 'Essex', 'tail': 'London'},
#  {'relation': 'has part', 'head': 'Industry', 'tail': 'agriculture'},
#  {'relation': 'part of', 'head': 'agriculture', 'tail': 'Industry'},
#  {'relation': 'instance of', 'head': 'electronics', 'tail': 'science'},
#  {'relation': 'headquarters location',
#   'head': 'Britvic',
#   'tail': 'Chelmsford'},
#  {'relation': 'headquarters location',
#   'head': 'New Holland Agriculture',
#   'tail': 'Basildon'},
#  {'relation': 'headquarters location',
#   'head': 'Ford Motor Company',
#   'tail': 'Basildon'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Debden',
#   'tail': 'Loughton'},
#  {'relation': 'subclass of',
#   'head': 'metalworking',
#   'tail': 'mechanical engineering'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'garrison town',
#   'tail': 'Colchester'},
#  {'relation': 'country', 'head': 'Basildon', 'tail': 'United Kingdom'},
#  {'relation': 'headquarters location',
#   'head': 'State Street Corporation',
#   'tail': 'Basildon'},
#  {'relation': 'country',
#   'head': 'State Street Corporation',
#   'tail': 'United Kingdom'},
#  {'relation': 'headquarters location',
#   'head': 'International Financial Data Services',
#   'tail': 'Basildon'},
#  {'relation': 'country',
#   'head': 'International Financial Data Services',
#   'tail': 'United Kingdom'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Adventure Island',
#   'tail': 'Southend-on-Sea'},
#  {'relation': 'instance of',
#   'head': 'Clacton.[timeframe?][11',
#   'tail': 'seaside town'},
#  {'relation': 'point in time',
#   'head': 'Indices of deprivation 2007',
#   'tail': '2007'},
#  {'relation': 'location',
#   'head': 'Brooklands and Grasslands',
#   'tail': 'Jaywick'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'eastern England'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'eastern England',
#   'tail': 'Essex'},
#  {'relation': 'subclass of',
#   'head': 'private schools',
#   'tail': 'middle class'},
#  {'relation': 'country', 'head': 'The Daily Telegraph', 'tail': 'UK'},
#  {'relation': 'instance of',
#   'head': 'settlement in the county',
#   'tail': 'pattern of settlement'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Metropolitan Green Belt',
#   'tail': 'London'},
#  {'relation': 'has part', 'head': 'Green Belt', 'tail': 'commuter towns'},
#  {'relation': 'part of', 'head': 'commuter towns', 'tail': 'Green Belt'},
#  {'relation': 'instance of', 'head': 'Basildon', 'tail': 'commuter towns'},
#  {'relation': 'instance of', 'head': 'Harlow', 'tail': 'commuter towns'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Epping Forest',
#   'tail': 'Greater London Urban Area'},
#  {'relation': 'shares border with', 'head': 'London', 'tail': 'Essex'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'London'},
#  {'relation': 'instance of', 'head': 'London', 'tail': 'capital'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'transport links',
#   'tail': 'Essex'},
#  {'relation': 'located in or next to body of water',
#   'head': 'Basildon',
#   'tail': 'Thames Gateway'},
#  {'relation': 'located in or next to body of water',
#   'head': 'Southend',
#   'tail': 'Thames Gateway'},
#  {'relation': 'located in or next to body of water',
#   'head': 'Thurrock',
#   'tail': 'Thames Gateway'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Greater London Urban Area',
#   'tail': 'Greater London'},
#  {'relation': 'is a list of',
#   'head': 'postcode district',
#   'tail': 'post town'},
#  {'relation': 'instance of', 'head': 'Chelmsford', 'tail': 'cities'},
#  {'relation': 'instance of', 'head': 'Southend-on-Sea', 'tail': 'cities'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'London commuter belt',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'rail links',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': "Essex's railway routes to London",
#   'tail': 'Essex'},
#  {'relation': 'operator', 'head': 'Essex Thameside franchise', 'tail': 'c2c'},
#  {'relation': 'operator', 'head': 'West Anglia', 'tail': 'Greater Anglia'},
#  {'relation': 'operator',
#   'head': 'Great Eastern Main Line',
#   'tail': 'Greater Anglia'},
#  {'relation': 'twinned administrative body',
#   'head': 'Essex',
#   'tail': 'London'},
#  {'relation': 'twinned administrative body',
#   'head': 'London',
#   'tail': 'Essex'},
#  {'relation': 'instance of', 'head': 'M25', 'tail': 'motorway'},
#  {'relation': 'crosses',
#   'head': 'Dartford Road Crossings',
#   'tail': 'Thames Estuary'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Kent'},
#  {'relation': 'shares border with', 'head': 'Kent', 'tail': 'Essex'},
#  {'relation': 'subclass of',
#   'head': 'radial commuter routes',
#   'tail': 'commuter routes'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'A120',
#   'tail': 'Suffolk'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'A12',
#   'tail': 'Suffolk'},
#  {'relation': 'country', 'head': 'Port of Tilbury', 'tail': 'Britain'},
#  {'relation': 'located in or next to body of water',
#   'head': 'Europoort',
#   'tail': 'Hook of Holland'},
#  {'relation': 'country', 'head': 'Esbjerg', 'tail': 'Denmark'},
#  {'relation': 'country', 'head': 'Cuxhaven', 'tail': 'Germany'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Shell Haven',
#   'tail': 'Thurrock'},
#  {'relation': 'field of work',
#   'head': 'wildlife organisations.[18][19][20',
#   'tail': 'environmental'},
#  {'relation': 'part of',
#   'head': 'branch lines',
#   'tail': 'national rail network'},
#  {'relation': 'has part',
#   'head': 'national rail network',
#   'tail': 'branch lines'},
#  {'relation': 'subclass of', 'head': 'commuter', 'tail': 'passenger'},
#  {'relation': 'located in or next to body of water',
#   'head': 'Dartford',
#   'tail': 'Thames Estuary'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Thames Estuary',
#   'tail': 'Kent'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Stansted Airport',
#   'tail': 'Essex'},
#  {'relation': 'has part',
#   'head': 'coalition government',
#   'tail': 'Conservative'},
#  {'relation': 'has part',
#   'head': 'coalition government',
#   'tail': 'Liberal Democrat'},
#  {'relation': 'has part',
#   'head': 'London Southend Airport',
#   'tail': 'railway station'},
#  {'relation': 'part of',
#   'head': 'railway station',
#   'tail': 'London Southend Airport'},
#  {'relation': 'connecting line',
#   'head': 'station',
#   'tail': 'Shenfield to Southend Line'},
#  {'relation': 'continent', 'head': 'Ireland', 'tail': 'Europe'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Clacton Airfield',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Earls Colne Airfield',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Stapleford Aerodrome',
#   'tail': 'Essex'},
#  {'relation': 'time period', 'head': 'Trinovantes', 'tail': 'Iron Age'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Trinovantes',
#   'tail': 'Essex'},
#  {'relation': 'instance of', 'head': 'Belgic', 'tail': 'tribes'},
#  {'relation': 'subclass of', 'head': 'oppidum', 'tail': 'town'},
#  {'relation': 'participant',
#   'head': 'extended conflict',
#   'tail': 'Catuvellauni'},
#  {'relation': 'capital of', 'head': 'Colchester', 'tail': 'Catuvellauni'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Richborough',
#   'tail': 'Kent'},
#  {'relation': 'position held', 'head': 'Claudius', 'tail': 'Emperor'},
#  {'relation': 'capital',
#   'head': 'Catevellauni-Trinovantes',
#   'tail': 'Colchester'},
#  {'relation': 'capital of',
#   'head': 'Colchester',
#   'tail': 'Catevellauni-Trinovantes'},
#  {'relation': 'position held', 'head': 'Claudius', 'tail': 'Imperator'},
#  {'relation': 'has part', 'head': 'legions', 'tail': 'mounted auxiliaries'},
#  {'relation': 'part of', 'head': 'mounted auxiliaries', 'tail': 'legions'},
#  {'relation': 'participant', 'head': 'Colchester', 'tail': 'Claudius'},
#  {'relation': 'instance of', 'head': 'Colchester', 'tail': 'Roman Colonia'},
#  {'relation': 'position held', 'head': 'Claudius', 'tail': 'God-Emperor'},
#  {'relation': 'part of', 'head': 'Roman Britain', 'tail': 'Britain'},
#  {'relation': 'has part', 'head': 'Britain', 'tail': 'Roman Britain'},
#  {'relation': 'participant', 'head': 'Boudiccan revolt.[30', 'tail': 'Iceni'},
#  {'relation': 'location',
#   'head': 'Massacre of the Ninth Legion',
#   'tail': 'Colchester'},
#  {'relation': 'has part', 'head': 'sack London', 'tail': 'St Albans'},
#  {'relation': 'part of', 'head': 'St Albans', 'tail': 'sack London'},
#  {'relation': 'conflict', 'head': 'Boudicca', 'tail': 'defeated in battle'},
#  {'relation': 'participant', 'head': 'defeated in battle', 'tail': 'Boudicca'},
#  {'relation': 'instance of', 'head': 'Trinovantes', 'tail': 'identity'},
#  {'relation': 'instance of', 'head': 'Trinovantes', 'tail': 'Roman provinces'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'a probable church',
#   'tail': 'Colchester,[33'},
#  {'relation': 'shares border with', 'head': 'Wickford', 'tail': 'Brentwood'},
#  {'relation': 'shares border with', 'head': 'Brentwood', 'tail': 'Wickford'},
#  {'relation': 'narrative location',
#   'head': 'King Cole',
#   'tail': 'Colchester.[35'},
#  {'relation': 'mother', 'head': 'Constantine the Great', 'tail': 'St Helena'},
#  {'relation': 'child',
#   'head': 'Coel, Duke of the Britons',
#   'tail': 'Constantine'},
#  {'relation': 'father',
#   'head': 'Constantine',
#   'tail': 'Coel, Duke of the Britons'},
#  {'relation': 'father', 'head': 'Constantine', 'tail': 'Constantius'},
#  {'relation': 'said to be the same as',
#   'head': 'St Helena',
#   'tail': 'the country'},
#  {'relation': 'said to be the same as',
#   'head': 'the country',
#   'tail': 'St Helena'},
#  {'relation': 'part of',
#   'head': 'Anglo-Saxon period',
#   'tail': 'Early Middle Ages'},
#  {'relation': 'has part',
#   'head': 'Early Middle Ages',
#   'tail': 'Anglo-Saxon period'},
#  {'relation': 'has part', 'head': 'Anglo-Saxon', 'tail': 'Trinovantes'},
#  {'relation': 'has part', 'head': 'Romano-British', 'tail': 'Saxon settlers'},
#  {'relation': 'part of', 'head': 'Saxon settlers', 'tail': 'Romano-British'},
#  {'relation': 'founded by', 'head': 'East Saxons', 'tail': 'Sledd'},
#  {'relation': 'religion', 'head': 'Seaxnēat', 'tail': 'pagan'},
#  {'relation': 'has part', 'head': 'S-nomenclature', 'tail': 'S'},
#  {'relation': 'capital', 'head': 'Middlesex', 'tail': 'City of London'},
#  {'relation': 'capital of', 'head': 'City of London', 'tail': 'Middlesex'},
#  {'relation': 'shares border with',
#   'head': 'Middlesex',
#   'tail': 'Hertfordshire'},
#  {'relation': 'shares border with',
#   'head': 'Hertfordshire',
#   'tail': 'Middlesex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Lea',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Mercian overlords',
#   'tail': 'Mercian'},
#  {'relation': 'religion', 'head': 'early kings', 'tail': 'pagan'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'St Pauls Cathedral',
#   'tail': 'London'},
#  {'relation': 'position held', 'head': 'Mellitus', 'tail': 'Bishop of London'},
#  {'relation': 'place of birth', 'head': 'St Cedd', 'tail': 'Lindisfarne'},
#  {'relation': 'father', 'head': 'Alfred the Great', 'tail': 'Ecgberht'},
#  {'relation': 'participant', 'head': 'Battle of Ellandun', 'tail': 'Ecgberht'},
#  {'relation': 'participant',
#   'head': 'Battle of Ellandun',
#   'tail': 'Alfred the Great'},
#  {'relation': 'replaced by', 'head': 'Essex', 'tail': 'Wessex'},
#  {'relation': 'replaced by', 'head': 'Sussex', 'tail': 'Wessex'},
#  {'relation': 'replaced by', 'head': 'Kent', 'tail': 'Wessex'},
#  {'relation': 'replaces', 'head': 'Wessex', 'tail': 'Essex'},
#  {'relation': 'replaces', 'head': 'Wessex', 'tail': 'Sussex'},
#  {'relation': 'replaces', 'head': 'Wessex', 'tail': 'Kent'},
#  {'relation': 'point in time', 'head': 'Battle of Assandun', 'tail': '1016'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'River Lea,[38',
#   'tail': 'Essex'},
#  {'relation': 'participant',
#   'head': 'Norman conquest',
#   'tail': 'Kingdom of England'},
#  {'relation': 'founded by',
#   'head': 'Tower of London',
#   'tail': 'William the Conqueror'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Barking',
#   'tail': 'England'},
#  {'relation': 'use', 'head': 'Castle', 'tail': 'protect the new elites'},
#  {'relation': 'instance of', 'head': 'Castle Hedingham', 'tail': 'Castle'},
#  {'relation': 'time period',
#   'head': 'Hadleigh Castle',
#   'tail': 'thirteenth century'},
#  {'relation': 'instance of',
#   'head': 'Forest of Essex',
#   'tail': 'Royal forest'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Forest of Essex',
#   'tail': 'Essex'},
#  {'relation': 'start time', 'head': 'Black Death', 'tail': '1348'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Writtle',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Kingswood',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Waltham Forest',
#   'tail': 'Waltham'},
#  {'relation': 'instance of',
#   'head': 'Epping Forest',
#   'tail': 'legally afforested'},
#  {'relation': 'instance of',
#   'head': 'Hainault Forest).[42',
#   'tail': 'legally afforested'},
#  {'relation': 'has effect',
#   'head': 'Black Death',
#   'tail': "reduced England's population"},
#  {'relation': 'has cause',
#   'head': "reduced England's population",
#   'tail': 'Black Death'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'national government',
#   'tail': 'national'},
#  {'relation': 'inception', 'head': 'Poll Tax', 'tail': '1381'},
#  {'relation': 'start time', 'head': "Peasants' Revolt", 'tail': '1 June 1381'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Bocking',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Bow Bridge',
#   'tail': 'Kent'},
#  {'relation': 'capital', 'head': 'Kent', 'tail': 'London'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Tower of London',
#   'tail': 'City of London'},
#  {'relation': 'position held',
#   'head': 'William Walworth',
#   'tail': 'Mayor of London'},
#  {'relation': 'position held', 'head': 'Richard II', 'tail': 'King'},
#  {'relation': 'part of', 'head': 'Essex', 'tail': 'elsewhere'},
#  {'relation': 'has part', 'head': 'elsewhere', 'tail': 'Essex'},
#  {'relation': 'subclass of', 'head': 'hangings', 'tail': 'mass executions'},
#  {'relation': 'subclass of',
#   'head': 'disembowelling',
#   'tail': 'mass executions'},
#  {'relation': 'participant',
#   'head': 'Wars of the Roses',
#   'tail': 'Lancastrian'},
#  {'relation': 'conflict',
#   'head': 'Bastard of Fauconberg',
#   'tail': 'Wars of the Roses'},
#  {'relation': 'part of', 'head': 'Aldgate', 'tail': 'Siege of London'},
#  {'relation': 'part of', 'head': 'Bishopsgate', 'tail': 'Siege of London'},
#  {'relation': 'has part', 'head': 'Siege of London', 'tail': 'Aldgate'},
#  {'relation': 'has part', 'head': 'Siege of London', 'tail': 'Bishopsgate'},
#  {'relation': 'shares border with', 'head': 'Lancastrians', 'tail': 'Essex'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Lancastrians'},
#  {'relation': 'conflict', 'head': 'Spanish Armada', 'tail': 'invade England'},
#  {'relation': 'start time', 'head': 'invade England', 'tail': '1588'},
#  {'relation': 'participant', 'head': 'invade England', 'tail': 'Philip II'},
#  {'relation': 'shares border with', 'head': 'English', 'tail': 'Spanish'},
#  {'relation': 'shares border with', 'head': 'Spanish', 'tail': 'English'},
#  {'relation': 'significant event',
#   'head': 'Queen Elizabeth',
#   'tail': 'famous speech to the troops'},
#  {'relation': 'author',
#   'head': 'famous speech to the troops',
#   'tail': 'Queen Elizabeth'},
#  {'relation': 'location',
#   'head': 'famous speech to the troops',
#   'tail': 'Tilbury'},
#  {'relation': 'continent', 'head': 'Spain', 'tail': 'Europe'},
#  {'relation': 'participant',
#   'head': 'English Civil War',
#   'tail': 'Parliament'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'River Lea',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'medieval walls',
#   'tail': 'Colchester'},
#  {'relation': 'location', 'head': 'Siege of Colchester', 'tail': 'Colchester'},
#  {'relation': 'significant event',
#   'head': 'Colchester',
#   'tail': 'Siege of Colchester'},
#  {'relation': 'instance of', 'head': 'Volunteer Force', 'tail': 'militia'},
#  {'relation': 'subclass of',
#   'head': 'Lord-Lieutenant of Essex',
#   'tail': 'justices of the peace'},
#  {'relation': 'main subject',
#   'head': 'County Rate.[48',
#   'tail': 'county prisons'},
#  {'relation': 'instance of', 'head': 'Hundreds', 'tail': 'units'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Stort',
#   'tail': 'Hertfordshire'},
#  {'relation': 'inception', 'head': 'Essex County Council', 'tail': '1889'},
#  {'relation': 'instance of', 'head': 'West Ham', 'tail': 'County Boroughs'},
#  {'relation': 'instance of',
#   'head': 'Southend-on-Sea',
#   'tail': 'County Boroughs'},
#  {'relation': 'instance of', 'head': 'East Ham', 'tail': 'County Boroughs'},
#  {'relation': 'shares border with', 'head': 'Essex', 'tail': 'Cambridgeshire'},
#  {'relation': 'shares border with', 'head': 'Cambridgeshire', 'tail': 'Essex'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Greater London',
#   'tail': 'Barking and Dagenham'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Greater London',
#   'tail': 'Havering'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Greater London',
#   'tail': 'Newham'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Greater London',
#   'tail': 'Redbridge'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Greater London',
#   'tail': 'Waltham Forest'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Barking and Dagenham',
#   'tail': 'Greater London'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Havering',
#   'tail': 'Greater London'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Newham',
#   'tail': 'Greater London'},
#  {'relation': 'located in the administrative territorial',
#   'head': 'Redbridge',
#   'tail': 'Greater London'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend-on-Sea',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Thurrock',
#   'tail': 'Essex'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'Southend-on-Sea'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'Thurrock'},
#  {'relation': 'instance of',
#   'head': 'Essex',
#   'tail': 'non-metropolitan county'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'County Hall',
#   'tail': 'Chelmsford'},
#  {'relation': 'point in time', 'head': '2011 census', 'tail': '2011'},
#  {'relation': 'has part', 'head': 'civil parish', 'tail': 'town'},
#  {'relation': 'part of', 'head': 'town', 'tail': 'civil parish'},
#  {'relation': 'has part', 'head': 'marriages', 'tail': 'civil partnerships'},
#  {'relation': 'part of', 'head': 'civil partnerships', 'tail': 'marriages'},
#  {'relation': 'inception', 'head': 'Essex', 'tail': '1889'},
#  {'relation': 'instance of',
#   'head': 'Southend-on-Sea Borough Council',
#   'tail': 'non-metropolitan county council'},
#  {'relation': 'instance of',
#   'head': 'Thurrock Council',
#   'tail': 'non-metropolitan county council'},
#  {'relation': 'instance of',
#   'head': 'Essex fire authority',
#   'tail': 'joint arrangements'},
#  {'relation': 'point in time',
#   'head': '2013 County Council elections',
#   'tail': '2013'},
#  {'relation': 'has part', 'head': 'Labour', 'tail': 'Liberal Democrats'},
#  {'relation': 'has part',
#   'head': 'official Opposition',
#   'tail': 'Liberal Democrats'},
#  {'relation': 'shares border with',
#   'head': 'Loughton',
#   'tail': 'Canvey Island'},
#  {'relation': 'shares border with',
#   'head': 'Canvey Island',
#   'tail': 'Loughton'},
#  {'relation': 'point in time',
#   'head': '2017 County Council elections',
#   'tail': '2017'},
#  {'relation': 'candidate',
#   'head': 'previous election',
#   'tail': 'Conservative Party'},
#  {'relation': 'has part', 'head': 'Conservatives', 'tail': 'firm control'},
#  {'relation': 'part of', 'head': 'firm control', 'tail': 'Conservatives'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'County Hall',
#   'tail': 'Chelmsford'},
#  {'relation': 'point in time', 'head': 'Before 1938', 'tail': '1938'},
#  {'relation': 'owned by', 'head': 'County Hall', 'tail': 'Courtaulds'},
#  {'relation': 'owner of', 'head': 'Courtaulds', 'tail': 'County Hall'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'East of England Government Office Region'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'East of England Government Office Region',
#   'tail': 'Essex'},
#  {'relation': 'replaces',
#   'head': 'East of England Government Office Region',
#   'tail': 'South East England'},
#  {'relation': 'replaced by',
#   'head': 'South East England',
#   'tail': 'East of England Government Office Region'},
#  {'relation': 'operating area',
#   'head': 'Essex Police',
#   'tail': 'administrative county'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'Essex County Council',
#   'tail': 'Essex'},
#  {'relation': 'instance of',
#   'head': 'Epping Forest,[56',
#   'tail': 'youth councils'},
#  {'relation': 'shares border with',
#   'head': 'Uttlesford[57',
#   'tail': 'Harlow.[58'},
#  {'relation': 'shares border with',
#   'head': 'Harlow.[58',
#   'tail': 'Uttlesford[57'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'councillors',
#   'tail': 'schools'},
#  {'relation': 'office held by head of the organization',
#   'head': 'schools',
#   'tail': 'councillors'},
#  {'relation': 'subclass of', 'head': 'unitary', 'tail': 'district'},
#  {'relation': 'said to be the same as', 'head': 'ward', 'tail': 'parish'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'county',
#   'tail': 'Essex'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'county'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'Southend on Sea'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Essex',
#   'tail': 'Thurrock'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend on Sea',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Thurrock',
#   'tail': 'Essex'},
#  {'relation': 'part of', 'head': 'housing', 'tail': 'local planning'},
#  {'relation': 'subclass of',
#   'head': 'local elections',
#   'tail': 'elected in parts'},
#  {'relation': 'different from', 'head': 'Town', 'tail': 'parish councils'},
#  {'relation': 'different from', 'head': 'parish councils', 'tail': 'Town'},
#  {'relation': 'different from', 'head': 'parish', 'tail': 'town council'},
#  {'relation': 'different from', 'head': 'town council', 'tail': 'parish'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'town and parish councils',
#   'tail': 'Essex.[59'},
#  {'relation': 'subclass of', 'head': 'allotments', 'tail': 'open spaces'},
#  {'relation': 'has effect',
#   'head': 'decision makers',
#   'tail': 'deliver services'},
#  {'relation': 'has cause',
#   'head': 'deliver services',
#   'tail': 'decision makers'},
#  {'relation': 'different from', 'head': 'powers', 'tail': 'duties'},
#  {'relation': 'different from', 'head': 'duties', 'tail': 'powers'},
#  {'relation': 'subclass of', 'head': 'district', 'tail': 'local councils'},
#  {'relation': 'subclass of', 'head': 'county', 'tail': 'local councils'},
#  {'relation': 'candidate',
#   'head': '2019 general election',
#   'tail': 'Conservatives'},
#  {'relation': 'candidacy in election',
#   'head': 'Thurrock',
#   'tail': '2005 election victory'},
#  {'relation': 'candidacy in election',
#   'head': 'Harlow',
#   'tail': '2005 election victory'},
#  {'relation': 'candidacy in election',
#   'head': 'Basildon',
#   'tail': '2005 election victory'},
#  {'relation': 'candidate',
#   'head': '2005 election victory',
#   'tail': 'Thurrock'},
#  {'relation': 'candidate', 'head': '2005 election victory', 'tail': 'Harlow'},
#  {'relation': 'candidate',
#   'head': '2005 election victory',
#   'tail': 'Basildon'},
#  {'relation': 'candidate',
#   'head': '1997 general election',
#   'tail': 'Liberal Democrats'},
#  {'relation': 'candidate',
#   'head': '2015 general election',
#   'tail': 'UK Independence Party'},
#  {'relation': 'followed by',
#   'head': '2015 general election',
#   'tail': '2017 general election'},
#  {'relation': 'candidacy in election',
#   'head': 'Douglas Carswell',
#   'tail': '2015 general election'},
#  {'relation': 'member of political party',
#   'head': 'Douglas Carswell',
#   'tail': 'UK Independence Party'},
#  {'relation': 'candidacy in election',
#   'head': 'Douglas Carswell',
#   'tail': '2014 by-election'},
#  {'relation': 'candidacy in election',
#   'head': 'Douglas Carswell',
#   'tail': '2017 general election'},
#  {'relation': 'candidate',
#   'head': '2014 by-election',
#   'tail': 'UK Independence Party'},
#  {'relation': 'successful candidate',
#   'head': '2014 by-election',
#   'tail': 'Douglas Carswell'},
#  {'relation': 'follows',
#   'head': '2017 general election',
#   'tail': '2015 general election'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend East',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend West',
#   'tail': 'Essex'},
#  {'relation': 'candidate', 'head': '2017', 'tail': 'UKIP'},
#  {'relation': 'candidacy in election',
#   'head': 'Alex Burghart',
#   'tail': '2017 election'},
#  {'relation': 'candidacy in election',
#   'head': 'Vicky Ford',
#   'tail': '2017 election'},
#  {'relation': 'candidacy in election',
#   'head': 'Giles Watling',
#   'tail': '2017 election'},
#  {'relation': 'candidacy in election',
#   'head': 'Kemi Badenoch',
#   'tail': '2017 election'},
#  {'relation': 'candidacy in election',
#   'head': 'Sir Eric Pickles',
#   'tail': '2017 election'},
#  {'relation': 'candidacy in election',
#   'head': 'Sir Simon Burns',
#   'tail': '2017 election'},
#  {'relation': 'candidacy in election',
#   'head': 'Douglas Carswell',
#   'tail': '2017 election'},
#  {'relation': 'candidacy in election',
#   'head': 'Sir Alan Haselhurst',
#   'tail': '2017 election'},
#  {'relation': 'candidate',
#   'head': '2019 general election',
#   'tail': 'Conservatives'},
#  {'relation': 'candidacy in election',
#   'head': 'Conservatives',
#   'tail': '2019 general election'},
#  {'relation': 'instance of', 'head': 'Colchester', 'tail': 'constituency'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Uttlesford.[60',
#   'tail': 'Essex'},
#  {'relation': 'depicts', 'head': 'coat of arms', 'tail': 'Gules'},
#  {'relation': 'depicts', 'head': 'coat of arms', 'tail': 'Or'},
#  {'relation': 'inception', 'head': 'Essex County Council', 'tail': '1932.[61'},
#  {'relation': 'part of', 'head': 'Essex', 'tail': 'Anglo-Saxon'},
#  {'relation': 'author',
#   'head': 'A Restitution of Decayed Intelligence',
#   'tail': 'Richard Verstegan'},
#  {'relation': 'publication date',
#   'head': 'A Restitution of Decayed Intelligence',
#   'tail': '1605'},
#  {'relation': 'location',
#   'head': 'Norman Conquest',
#   'tail': 'Anglo-Saxon period'},
#  {'relation': 'author',
#   'head': 'Historie of Great Britaine',
#   'tail': 'John Speed'},
#  {'relation': 'facet of', 'head': 'apostasised', 'tail': 'Christianity'},
#  {'relation': 'religion',
#   'head': 'Sigeberht the Good',
#   'tail': 'Christianity'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Othona',
#   'tail': 'Bradwell-on-Sea'},
#  {'relation': 'different from',
#   'head': 'Bishop of London',
#   'tail': 'Bishop of the East Saxons'},
#  {'relation': 'different from',
#   'head': 'Bishop of the East Saxons',
#   'tail': 'Bishop of London'},
#  {'relation': 'named after', 'head': 'Essex Day', 'tail': 'St Cedd'},
#  {'relation': 'instance of', 'head': 'Essex.[63', 'tail': 'county'},
#  {'relation': 'indigenous to', 'head': 'Essex dialect', 'tail': 'Essex'},
#  {'relation': 'subclass of',
#   'head': 'Cockney',
#   'tail': 'Received Pronunciation'},
#  {'relation': 'has part', 'head': 'Cockney Diaspora', 'tail': 'Cockney'},
#  {'relation': 'subclass of', 'head': 'Cockney', 'tail': 'Estuary English.[65'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Dunmow Flitch Trials',
#   'tail': 'Essex'},
#  {'relation': 'religious order',
#   'head': 'Lady Juga Baynard',
#   'tail': 'Augustinian'},
#  {'relation': 'position held',
#   'head': 'Reginald Fitzwalter',
#   'tail': 'Lord of the Manor'},
#  {'relation': 'has part', 'head': 'Flitch', 'tail': 'bacon'},
#  {'relation': 'location', 'head': 'Flitch Trials', 'tail': 'Dunmow'},
#  {'relation': 'author',
#   'head': 'The Vision of Piers Plowman',
#   'tail': 'William Langland'},
#  {'relation': 'publication date',
#   'head': 'The Vision of Piers Plowman',
#   'tail': '1362'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend United',
#   'tail': 'Metropolitan Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Colchester United',
#   'tail': 'Metropolitan Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'West Ham United',
#   'tail': 'Metropolitan Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Leyton Orient',
#   'tail': 'Metropolitan Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Dagenham & Redbridge',
#   'tail': 'Metropolitan Essex'},
#  {'relation': 'operating area', 'head': 'fifth tier', 'tail': 'English'},
#  {'relation': 'league',
#   'head': 'Billericay Town',
#   'tail': 'National League South'},
#  {'relation': 'league',
#   'head': 'Braintree Town',
#   'tail': 'National League South'},
#  {'relation': 'league',
#   'head': 'Chelmsford City',
#   'tail': 'National League South'},
#  {'relation': 'league',
#   'head': 'Concord Rangers',
#   'tail': 'National League South'},
#  {'relation': 'winner', 'head': '2006', 'tail': 'Grays Athletic'},
#  {'relation': 'sports season of league or competition',
#   'head': '1976',
#   'tail': 'FA Vase'},
#  {'relation': 'winner', 'head': '1976', 'tail': 'Billericay Town'},
#  {'relation': 'sports season of league or competition',
#   'head': '1977',
#   'tail': 'FA Vase'},
#  {'relation': 'winner', 'head': '1977', 'tail': 'Billericay Town'},
#  {'relation': 'sports season of league or competition',
#   'head': '1979',
#   'tail': 'FA Vase'},
#  {'relation': 'winner', 'head': '1979', 'tail': 'Billericay Town'},
#  {'relation': 'sports season of league or competition',
#   'head': '1984',
#   'tail': 'FA Vase'},
#  {'relation': 'winner', 'head': '1984', 'tail': 'Stansted'},
#  {'relation': 'inception',
#   'head': 'Essex County Cricket Club',
#   'tail': '1894'},
#  {'relation': 'sport', 'head': 'Romford Raiders', 'tail': 'ice hockey'},
#  {'relation': 'sport', 'head': 'Chelmsford Chieftains', 'tail': 'ice hockey'},
#  {'relation': 'sport', 'head': 'Essex Leopards', 'tail': 'basketball'},
#  {'relation': 'sport', 'head': 'Eastern Rhinos', 'tail': 'rugby league'},
#  {'relation': 'sport', 'head': 'Brentwood Eels', 'tail': 'rugby league'},
#  {'relation': 'sport', 'head': 'Lakeside Hammers', 'tail': 'speedway'},
#  {'relation': 'point in time', 'head': '2012 London Olympics', 'tail': '2012'},
#  {'relation': 'has part',
#   'head': '2012 London Olympics',
#   'tail': 'mountain bike races'},
#  {'relation': 'part of',
#   'head': 'mountain bike races',
#   'tail': '2012 London Olympics'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'London Stadium',
#   'tail': 'Essex'},
#  {'relation': 'sport',
#   'head': 'Chelmsford City Racecourse',
#   'tail': 'horse racing'},
#  {'relation': 'sport',
#   'head': 'Chelmsford Racecourse',
#   'tail': 'horse racing'},
#  {'relation': 'sport', 'head': 'Harlow Stadium', 'tail': 'greyhound racing'},
#  {'relation': 'sport', 'head': 'Rayleigh Weir Stadium', 'tail': 'greyhound'},
#  {'relation': 'sport', 'head': 'Southend Stadium', 'tail': 'greyhound'},
#  {'relation': 'sport',
#   'head': 'Team Essex Volleyball Club',
#   'tail': 'Volleyball'},
#  {'relation': 'sport', 'head': 'Volleyball England', 'tail': 'Volleyball'},
#  {'relation': 'sports league level', 'head': 'Super 8s', 'tail': '1st'},
#  {'relation': 'location', 'head': 'The Boswells School', 'tail': 'Chelmsford'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'BBC East',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'ITV Anglia',
#   'tail': 'Essex'},
#  {'relation': 'sport', 'head': 'Trevor Bailey', 'tail': 'cricket'},
#  {'relation': 'sport', 'head': 'Nasser Hussain', 'tail': 'cricket'},
#  {'relation': 'sport', 'head': 'Alastair Cook', 'tail': 'cricket'},
#  {'relation': 'sport', 'head': 'Graham Gooch', 'tail': 'cricket'},
#  {'relation': 'sport', 'head': 'Peter Taylor', 'tail': 'footballers'},
#  {'relation': 'sport', 'head': 'James Tomkins', 'tail': 'footballers'},
#  {'relation': 'sport', 'head': 'Justin Edinburgh', 'tail': 'footballers'},
#  {'relation': 'sport', 'head': 'Nigel Spink', 'tail': 'footballers'},
#  {'relation': 'sport', 'head': 'John Lloyd', 'tail': 'tennis'},
#  {'relation': 'sport', 'head': 'David Lloyd', 'tail': 'tennis'},
#  {'relation': 'sport', 'head': 'Max Whitlock', 'tail': 'gymnast'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'Essex County Council',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend-on-Sea',
#   'tail': 'Essex'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Thurrock',
#   'tail': 'Essex'},
#  {'relation': 'subclass of',
#   'head': 'comprehensive',
#   'tail': 'secondary schools'},
#  {'relation': 'subclass of',
#   'head': 'grammar schools',
#   'tail': 'secondary schools'},
#  {'relation': 'inception', 'head': 'University of Essex', 'tail': '1963'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'University Campus Suffolk',
#   'tail': 'Ipswich'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Anglia Ruskin University',
#   'tail': 'Chelmsford'},
#  {'relation': 'has part',
#   'head': 'Lord Ashcroft International Business School',
#   'tail': 'Anglia Law School'},
#  {'relation': 'part of',
#   'head': 'Anglia Law School',
#   'tail': 'Lord Ashcroft International Business School'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Writtle University College',
#   'tail': 'Writtle'},
#  {'relation': 'point in time',
#   'head': 'International Exhibition of Modern Architecture',
#   'tail': '1932'},
#  {'relation': 'instance of', 'head': 'Southend Pier', 'tail': 'pleasure pier'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'St Peter-on-the-Wall',
#   'tail': 'Bradwell-on-Sea'},
#  {'relation': 'architectural style',
#   'head': 'Hedingham Castle',
#   'tail': 'Norman'},
#  {'relation': 'inception', 'head': 'Thaxted Guildhall', 'tail': '1450'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Audley End House',
#   'tail': 'Saffron Walden'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Royal Corinthian Yacht Club',
#   'tail': 'Burnham-on-Crouch'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Colchester Castle',
#   'tail': 'Colchester'},
#  {'relation': 'shares border with', 'head': 'Writtle', 'tail': 'Chelmsford'},
#  {'relation': 'shares border with', 'head': 'Chelmsford', 'tail': 'Writtle'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Southend Pier',
#   'tail': 'Southend-on-Sea'},
#  {'relation': 'instance of', 'head': 'image', 'tail': 'MIME type'},
#  {'relation': 'instance of', 'head': 'jpeg', 'tail': 'MIME type'},
#  {'relation': 'different from', 'head': 'date', 'tail': 'time'},
#  {'relation': 'different from', 'head': 'time', 'tail': 'date'},
#  {'relation': 'has part', 'head': 'wikis', 'tail': 'wikis'},
#  {'relation': 'use', 'head': 'digital camera', 'tail': 'digitize'},
#  {'relation': 'opposite of', 'head': 'modified', 'tail': 'original state'},
#  {'relation': 'opposite of', 'head': 'original state', 'tail': 'modified'},
#  {'relation': 'subclass of', 'head': 'Mazda3', 'tail': 'compact car'},
#  {'relation': 'manufacturer', 'head': 'Mazda3', 'tail': 'Mazda'},
#  {'relation': 'subclass of',
#   'head': 'Familia/323/Protegé',
#   'tail': 'C-segment'},
#  {'relation': 'part of the series',
#   'head': 'second-generation Mazda3',
#   'tail': 'Mazda3'},
#  {'relation': 'has part',
#   'head': 'Mazda3',
#   'tail': 'second-generation Mazda3'},
#  {'relation': 'manufacturer', 'head': 'Mazda3', 'tail': 'Mazda'},
#  {'relation': 'point in time', 'head': '2014 model year', 'tail': '2014'},
#  {'relation': 'instance of', 'head': 'Kodo', 'tail': 'design language'},
#  {'relation': 'followed by',
#   'head': 'fourth-generation Mazda3',
#   'tail': '2019 model year'},
#  {'relation': 'follows',
#   'head': '2019 model year',
#   'tail': 'fourth-generation Mazda3'},
#  {'relation': 'part of the series', 'head': '2019 model', 'tail': 'Mazda3'},
#  {'relation': 'has part', 'head': 'Mazda3', 'tail': '2019 model'},
#  {'relation': 'part of the series', 'head': 'Mazda3 MPS', 'tail': 'Mazda3'},
#  {'relation': 'manufacturer', 'head': 'Mazda3', 'tail': 'Mazda'},
#  {'relation': 'part of the series', 'head': 'Mazda3', 'tail': 'BK series'},
#  {'relation': 'said to be the same as',
#   'head': 'sports sedan',
#   'tail': 'saloon'},
#  {'relation': 'said to be the same as',
#   'head': 'saloon',
#   'tail': 'sports sedan'},
#  {'relation': 'point in time',
#   'head': 'second best-selling car in Canada',
#   'tail': '2006'},
#  {'relation': 'subclass of',
#   'head': 'Ford Focus',
#   'tail': 'Ford global C1 platform'},
#  {'relation': 'subclass of',
#   'head': 'Volvo S40',
#   'tail': 'Ford global C1 platform'},
#  {'relation': 'instance of', 'head': 'MX-Sportif', 'tail': 'concept car'},
#  {'relation': 'country', 'head': 'California', 'tail': 'United States'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'United States',
#   'tail': 'California'},
#  {'relation': 'country', 'head': 'Hiroshima', 'tail': 'Japan'},
#  {'relation': 'point in time', 'head': '2003 production', 'tail': '2003'},
#  {'relation': 'has part', 'head': 'MacPherson struts', 'tail': 'coil springs'},
#  {'relation': 'has part',
#   'head': 'MacPherson struts',
#   'tail': 'anti-roll bar'},
#  {'relation': 'part of', 'head': 'anti-roll bar', 'tail': 'MacPherson struts'},
#  {'relation': 'connects with',
#   'head': 'coil springs',
#   'tail': 'shock absorbers'},
#  {'relation': 'connects with',
#   'head': 'shock absorbers',
#   'tail': 'coil springs'},
#  {'relation': 'part of the series',
#   'head': 'first generation',
#   'tail': 'Mazda 3'},
#  {'relation': 'has part', 'head': 'Mazda 3', 'tail': 'first generation'},
#  {'relation': 'has part', 'head': 'ABS', 'tail': 'Disc brakes'},
#  {'relation': 'connects with', 'head': 'wheel', 'tail': 'tire'},
#  {'relation': 'connects with', 'head': 'tire', 'tail': 'wheel'},
#  {'relation': 'applies to jurisdiction',
#   'head': 'Public Security Police Force of Macau',
#   'tail': 'Macau'},
#  {'relation': 'country',
#   'head': 'Public Security Police Force of Macau',
#   'tail': 'China'},
#  {'relation': 'country', 'head': 'Macau', 'tail': 'China'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'China',
#   'tail': 'Macau'},
#  {'relation': 'has part', 'head': 'Mazda3', 'tail': 'i'},
#  {'relation': 'has part', 'head': 'Mazda3', 'tail': 's'},
#  {'relation': 'part of the series', 'head': 'i', 'tail': 'Mazda3'},
#  {'relation': 'part of the series', 'head': 's', 'tail': 'Mazda3'},
#  {'relation': 'subclass of', 'head': 'Grand Touring', 'tail': 'Touring'},
#  {'relation': 'part of the series', 'head': 'TS', 'tail': 'Mazda3'},
#  {'relation': 'part of the series', 'head': 'TS2', 'tail': 'Mazda3'},
#  {'relation': 'part of the series', 'head': 'Sport', 'tail': 'Mazda3'},
#  {'relation': 'follows', 'head': 'Takara', 'tail': 'TS & TS2'},
#  {'relation': 'followed by', 'head': 'TS & TS2', 'tail': 'Takara'},
#  {'relation': 'part of the series', 'head': 'MZ-CD', 'tail': 'Mazda MZR'},
#  {'relation': 'subclass of',
#   'head': 'manual transmission',
#   'tail': 'transmission'},
#  {'relation': 'subclass of',
#   'head': 'automatic transmission',
#   'tail': 'transmission'},
#  {'relation': 'subclass of', 'head': 'FWD', 'tail': 'engine'},
#  {'relation': 'follows', 'head': 'Mazdaspeed', 'tail': 'MPS'},
#  {'relation': 'has parts of the class', 'head': 'Mazda3', 'tail': 'engines'},
#  {'relation': 'country', 'head': 'JIS ratings', 'tail': 'Japanese'},
#  {'relation': 'facet of', 'head': 'ECE ratings', 'tail': 'European market'},
# ...
#  {'relation': 'headquarters location',
#   'head': 'Buderim Ginger',
#   'tail': 'Buderim'},
#  {'relation': 'instance of', 'head': 'Big Thing', 'tail': 'advertising'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Big Thing',
#   'tail': 'California'},
#  {'relation': 'part of', 'head': 'produce', 'tail': 'flora'},
#  {'relation': 'subclass of',
#   'head': 'fibreglass',
#   'tail': 'building materials.[1'},
#  {'relation': 'inception', 'head': 'Woombye', 'tail': 'January 1971'},
#  {'relation': 'spouse', 'head': 'Bill Taylor', 'tail': 'Lyn Taylor'},
#  {'relation': 'spouse', 'head': 'Lyn Taylor', 'tail': 'Bill Taylor'},
#  {'relation': 'industry',
#   'head': 'Sunshine Plantation',
#   'tail': 'agri-tourism'},
#  {'relation': 'employer',
#   'head': 'John Herbert',
#   'tail': 'Queensland Government'},
#  {'relation': 'instance of', 'head': 'tourism', 'tail': 'industry'},
#  {'relation': 'inception', 'head': 'Sunshine Plantation', 'tail': '1971'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Maroochy Shire Council',
#   'tail': 'Queensland'},
#  {'relation': 'contains administrative territorial entity',
#   'head': 'Queensland',
#   'tail': 'Maroochy Shire Council'},
#  {'relation': 'instance of', 'head': 'Big Pineapple', 'tail': 'fibreglass'},
#  {'relation': 'field of work', 'head': 'Lyn Taylor', 'tail': 'design'},
#  {'relation': 'subclass of', 'head': 'Pineapple', 'tail': 'tropical fruits'},
#  {'relation': 'instance of',
#   'head': 'Golden Circle Cannery',
#   'tail': 'co-operatives'},
#  {'relation': 'product or material produced',
#   'head': 'market',
#   'tail': 'sugar cane'},
#  {'relation': 'subclass of', 'head': 'fruit jams', 'tail': 'tropical'},
#  {'relation': 'inception',
#   'head': 'Sunshine Tropical Fruit Products.[1',
#   'tail': '1972'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Sunshine Plantation',
#   'tail': 'Queensland'},
#  {'relation': 'part of', 'head': 'sugar cane', 'tail': 'Plantation'},
#  {'relation': 'product or material produced',
#   'head': 'Plantation',
#   'tail': 'sugar cane'},
#  {'relation': 'subclass of', 'head': 'fruit jams.[1', 'tail': 'fruit'},
#  {'relation': 'instance of',
#   'head': 'Golden Circle Cannery',
#   'tail': 'co-operatives'},
#  {'relation': 'followed by', 'head': 'Big Pineapple', 'tail': 'Big Things'},
#  {'relation': 'follows', 'head': 'Big Things', 'tail': 'Big Pineapple'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Gympie',
#   'tail': 'Queensland'},
#  {'relation': 'inception', 'head': 'Big Cow', 'tail': '1976'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Sunshine Plantation',
#   'tail': 'Queensland'},
#  {'relation': 'inception',
#   'head': 'Hawaii Tropical Plantation',
#   'tail': '1984'},
#  {'relation': 'inception', 'head': 'Sunshine Plantation', 'tail': '1976'},
#  {'relation': 'dissolved, abolished or demolished date',
#   'head': 'Big Pineapple',
#   'tail': '11 September 1978'},
#  {'relation': 'position held',
#   'head': 'Zelman Cowan',
#   'tail': 'Governor General'},
#  {'relation': 'owned by', 'head': 'Nut Factory', 'tail': 'Heinrichs'},
#  {'relation': 'owner of', 'head': 'Heinrichs', 'tail': 'Nut Factory'},
#  {'relation': 'inception', 'head': 'CSR Limited', 'tail': '1979'},
#  {'relation': 'inception', 'head': 'Sunshine Plantation', 'tail': '1980'},
#  {'relation': 'inception', 'head': 'Tropical Restaurant', 'tail': '1980'},
#  {'relation': 'has part',
#   'head': 'Polynesian Restaurant',
#   'tail': 'Hibiscus Room'},
#  {'relation': 'part of',
#   'head': 'Hibiscus Room',
#   'tail': 'Polynesian Restaurant'},
#  {'relation': 'country', 'head': 'Macadamia Nut Factory', 'tail': 'Australia'},
#  {'relation': 'instance of',
#   'head': "Tomorrow's Harvest",
#   'tail': 'greenhouse'},
#  {'relation': 'has part', 'head': "Children's Farm", 'tail': 'Animal Nursery'},
#  {'relation': 'part of', 'head': 'Animal Nursery', 'tail': "Children's Farm"},
#  {'relation': 'part of',
#   'head': 'tunnel under the train track',
#   'tail': 'rainforest walk.[1'},
#  {'relation': 'has part',
#   'head': 'rainforest walk.[1',
#   'tail': 'tunnel under the train track'},
#  {'relation': 'inception', 'head': 'Sunshine Plantation', 'tail': '1972'},
#  {'relation': 'point in time', 'head': '1980s', 'tail': '1980'},
#  {'relation': 'owned by',
#   'head': 'Sunshine Plantation',
#   'tail': 'Lanray Holdings'},
#  {'relation': 'inception', 'head': 'Nutcountry Tour', 'tail': '1984'},
#  {'relation': 'instance of',
#   'head': 'Sunshines Restaurant',
#   'tail': 'restaurant'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': "Queensland's Hidden Treasures",
#   'tail': 'Queensland'},
#  {'relation': 'inception', 'head': 'Queensland Press Limited', 'tail': '1985'},
#  {'relation': 'crosses', 'head': 'pedestrian bridge', 'tail': 'highway'},
#  {'relation': 'inception', 'head': 'Sunshines Restaurant', 'tail': '1987'},
#  {'relation': 'has part',
#   'head': 'The Big Pineapple',
#   'tail': 'Big Pineapple'},
#  {'relation': 'part of', 'head': 'Big Pineapple', 'tail': 'The Big Pineapple'},
#  {'relation': 'instance of', 'head': 'Big Pineapple', 'tail': 'skin'},
#  {'relation': 'inception', 'head': "Tomorrow's Harvest", 'tail': '1988'},
#  {'relation': 'inception', 'head': 'Magic Macadamia', 'tail': '1989'},
#  {'relation': 'inception',
#   'head': 'Rainforest Creatures of the Night',
#   'tail': '2000'},
#  {'relation': 'location',
#   'head': 'Nutmobile Tour',
#   'tail': 'Macadamia Nut Factory'},
#  {'relation': 'point in time', 'head': '1990s', 'tail': '1990'},
#  {'relation': 'dissolved, abolished or demolished date',
#   'head': "Tomorrow's Harvest",
#   'tail': '1991'},
#  {'relation': 'date of official opening',
#   'head': 'Rainforest train stop',
#   'tail': 'December 1991'},
#  {'relation': 'inception', 'head': 'Arts and Crafts Gallery', 'tail': '1992'},
#  {'relation': 'subclass of', 'head': 'punkahs', 'tail': 'fans'},
#  {'relation': 'point in time',
#   'head': '1994 Sunshines Restaurant',
#   'tail': '1994'},
#  {'relation': 'dissolved, abolished or demolished date',
#   'head': 'RAPS restaurant',
#   'tail': 'September that year'},
#  {'relation': 'inception', 'head': 'The Farm Show', 'tail': 'September 1995'},
#  {'relation': 'country', 'head': 'Wildlife Garden', 'tail': 'Australian'},
#  {'relation': 'endemic to', 'head': 'koalas', 'tail': 'Australian'},
#  {'relation': 'inception',
#   'head': "Tomorrow's Harvest",
#   'tail': 'February 1996'},
#  {'relation': 'has part', 'head': 'Wildlife Garden', 'tail': 'koalas'},
#  {'relation': 'has part', 'head': 'Wildlife Garden', 'tail': 'native animals'},
#  {'relation': 'part of', 'head': 'koalas', 'tail': 'Wildlife Garden'},
#  {'relation': 'part of', 'head': 'native animals', 'tail': 'Wildlife Garden'},
#  {'relation': 'owned by',
#   'head': 'Sunshine Plantation',
#   'tail': 'Roughend Pineapple'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Big Pineapple',
#   'tail': 'Queensland'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Cane Toad',
#   'tail': 'Queensland'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Macadamia Nuts',
#   'tail': 'Queensland'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Great Barrier Reef',
#   'tail': 'Queensland'},
#  {'relation': 'followed by', 'head': '2004', 'tail': '2005'},
#  {'relation': 'follows', 'head': '2005', 'tail': '2004'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'National Trust of Queensland',
#   'tail': 'Queensland'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Tamworth',
#   'tail': 'New South Wales'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Coffs Harbour',
#   'tail': 'New South Wales'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Goulburn',
#   'tail': 'New South Wales'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Kingston SE',
#   'tail': 'South Australia).[1'},
#  {'relation': 'dissolved, abolished or demolished date',
#   'head': 'Big Pineapple',
#   'tail': '2009'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Nutmobile',
#   'tail': 'Bauple'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Big Pineapple',
#   'tail': 'Queensland'},
#  {'relation': 'inception',
#   'head': 'Big Pineapple Music Festival',
#   'tail': 'April 2013'},
#  {'relation': 'instance of',
#   'head': 'The Music Festival',
#   'tail': 'Music Festival'},
#  {'relation': 'facet of',
#   'head': 'heritage and qualities',
#   'tail': 'heritage'},
#  {'relation': 'subclass of',
#   'head': 'glamping',
#   'tail': 'holiday recreational vehicle park'},
#  {'relation': 'point in time', 'head': '1980s.[5', 'tail': '1980s.[5'},
#  {'relation': 'location',
#   'head': 'Big Pineapple Music Festival',
#   'tail': 'Big Pineapple'},
#  {'relation': 'part of the Pineapple',
#   'head': 'Pineapple',
#   'tail': 'the Pineapple'},
#  {'relation': 'country', 'head': 'royal visit', 'tail': 'Australia'},
#  {'relation': 'country', 'head': 'the Big Pineapple', 'tail': 'Australia'},
#  {'relation': 'instance of',
#   'head': 'Big Pineapple',
#   'tail': 'music festival'},
#  {'relation': 'location',
#   'head': 'TreeTop Challenge',
#   'tail': 'Big Pineapple'},
#  {'relation': 'located in the administrative territorial entity',
#   'head': 'Big Pineapple',
#   'tail': 'Woombye'},
#  {'relation': 'area', 'head': 'Sunshine Plantation', 'tail': '22.86'},
#  {'relation': 'instance of', 'head': 'Big Pineapple', 'tail': 'Pineapple'},
#  {'relation': 'has part', 'head': 'tram tracks', 'tail': 'Tour station'},
#  {'relation': 'has part', 'head': 'tram tracks', 'tail': 'plantation train'},
#  {'relation': 'part of', 'head': 'Tour station', 'tail': 'tram tracks'},
#  {'relation': 'part of', 'head': 'plantation train', 'tail': 'tram tracks'},
#  {'relation': 'part of', 'head': 'Nutmobile', 'tail': 'Rainforest Tour'},
#  {'relation': 'has part', 'head': 'Rainforest Tour', 'tail': 'Nutmobile'},
#  {'relation': 'has part',
#   'head': 'The Big Pineapple',
#   'tail': 'Big Pineapple'},
#  {'relation': 'part of', 'head': 'Big Pineapple', 'tail': 'The Big Pineapple'},
#  {'relation': 'instance of',
#   'head': 'Big Pineapple',
#   'tail': 'pineapple plantation'},
#  {'relation': 'subclass of', 'head': 'entrance pavilion', 'tail': 'pavilion'},
#  {'relation': 'subclass of', 'head': 'corrugated iron', 'tail': 'roof.[1'},
#  {'relation': 'length', 'head': 'Big Pineapple', 'tail': '16'},
#  {'relation': 'subclass of', 'head': 'fibreglass', 'tail': 'shell'},
#  {'relation': 'product or material produced',
#   'head': 'moulded',
#   'tail': 'fibreglass'},
#  {'relation': 'part of', 'head': 'steel', 'tail': 'viewing platform'},
#  {'relation': 'part of', 'head': 'shell', 'tail': 'moulding'},
#  {'relation': 'has part', 'head': 'moulding', 'tail': 'shell'},
#  {'relation': 'has part', 'head': 'displays', 'tail': 'viewing platform'},
#  {'relation': 'part of', 'head': 'viewing platform', 'tail': 'displays'},
#  {'relation': 'has part', 'head': 'floor', 'tail': 'posts'},
#  {'relation': 'part of', 'head': 'posts', 'tail': 'floor'},
#  {'relation': 'part of', 'head': 'stalk', 'tail': 'Pineapple'},
#  {'relation': 'has part', 'head': 'Pineapple', 'tail': 'stalk'},
#  {'relation': 'has part', 'head': 'first level', 'tail': 'steps'},
#  {'relation': 'part of', 'head': 'steps', 'tail': 'first level'},
#  {'relation': 'part of', 'head': 'fibre-cement', 'tail': 'ceiling'},
#  {'relation': 'subclass of', 'head': 'linoleum', 'tail': 'tiles'},
#  {'relation': 'part of', 'head': 'balustrade.[1', 'tail': 'staircase'},
#  {'relation': 'subclass of', 'head': 'linoleum', 'tail': 'tiled'},
#  {'relation': 'subclass of', 'head': 'fibre-cement', 'tail': 'timber'},
#  {'relation': 'subclass of',
#   'head': 'two-flight staircase',
#   'tail': 'viewing platform'},
#  {'relation': 'subclass of', 'head': 'balustrade', 'tail': 'treads'},
#  {'relation': 'part of',
#   'head': 'stalk of the pineapple',
#   'tail': 'pineapple shell'},
#  {'relation': 'subclass of', 'head': 'spray-aggregate', 'tail': 'sheet metal'},
#  {'relation': 'inception', 'head': 'Big Pineapple', 'tail': '1971'},
#  {'relation': 'depicts', 'head': 'diorama', 'tail': 'model factories'},
#  {'relation': 'followed by', 'head': 'one', 'tail': 'two'},
#  {'relation': 'follows', 'head': 'two', 'tail': 'one'},
#  {'relation': 'product or material produced',
#   'head': 'Golden Circle Cannery',
#   'tail': 'cordial'},
#  {'relation': 'subclass of',
#   'head': 'tropical fruit',
#   'tail': 'manufacturing'},
#  {'relation': 'product or material produced',
#   'head': 'manufacturing',
#   'tail': 'tropical fruit'},
#  {'relation': 'subclass of', 'head': 'ring', 'tail': 'beam'},
#  {'relation': 'subclass of',
#   'head': 'Polynesian architectural influences',
#   'tail': 'restaurant'},
#  {'relation': 'has part', 'head': 'restaurant', 'tail': 'retail building'},
#  {'relation': 'subclass of', 'head': 'gablets', 'tail': 'hipped roofs'},
#  {'relation': 'subclass of', 'head': 'verandah', 'tail': 'overhangs'},
#  {'relation': 'part of', 'head': 'portal frames', 'tail': 'roof.[1'},
#  {'relation': 'has part', 'head': 'roof.[1', 'tail': 'portal frames'},
#  {'relation': 'subclass of', 'head': 'fibre-cement', 'tail': 'brick'},
#  {'relation': 'part of', 'head': 'rafters', 'tail': 'verandah'},
#  {'relation': 'part of', 'head': 'glazing', 'tail': 'Walls'},
#  {'relation': 'part of', 'head': 'glazing', 'tail': 'blockwork'},
#  {'relation': 'part of', 'head': 'balustrades.[1', 'tail': 'verandah'},
#  {'relation': 'part of', 'head': 'gabled', 'tail': 'roof'},
#  {'relation': 'subclass of', 'head': 'service areas', 'tail': 'Amenities'},
#  {'relation': 'different from',
#   'head': 'station.[1',
#   'tail': 'train station.[1'},
#  {'relation': 'different from',
#   'head': 'train station.[1',
#   'tail': 'station.[1'},
#  {'relation': 'part of',
#   'head': 'steel portal frame',
#   'tail': 'retail building'},
#  {'relation': 'subclass of', 'head': 'linoleum', 'tail': 'tiled'},
#  {'relation': 'part of', 'head': 'souvenir', 'tail': 'retail'},
#  {'relation': 'subclass of', 'head': 'punkah', 'tail': 'air conditioning'},
#  {'relation': 'subclass of',
#   'head': 'fluorescent tubes',
#   'tail': 'Pendant lights'},
#  {'relation': 'connects with',
#   'head': 'central staircase',
#   'tail': 'lower level'},
#  {'relation': 'connects with',
#   'head': 'lower level',
#   'tail': 'central staircase'},
#  {'relation': 'different from',
#   'head': 'restaurant',
#   'tail': 'retail building'},
#  {'relation': 'different from',
#   'head': 'retail building',
#   'tail': 'restaurant'},
#  {'relation': 'connects with', 'head': 'portal frame', 'tail': 'ceiling'},
#  {'relation': 'connects with', 'head': 'ceiling', 'tail': 'portal frame'},
#  {'relation': 'part of', 'head': 'servery', 'tail': 'kitchen'},
#  {'relation': 'subclass of', 'head': 'carpet', 'tail': 'floor'},
#  {'relation': 'use', 'head': 'plasterboard', 'tail': 'painted'},
#  {'relation': 'has part',
#   'head': 'ceiling fans',
#   'tail': 'Air conditioning vents'},
#  {'relation': 'connects with',
#   'head': 'plantation railway ticket office',
#   'tail': 'plantation train'},
#  {'relation': 'connects with',
#   'head': 'plantation train',
#   'tail': 'plantation railway ticket office'},
#  {'relation': 'part of', 'head': 'platform', 'tail': 'station'},
#  {'relation': 'instance of', 'head': 'two foot gauge', 'tail': 'track gauge'},
#  {'relation': 'part of', 'head': 'koala sanctuary', 'tail': 'rainforest walk'},
#  {'relation': 'has part',
#   'head': 'rainforest walk',
#   'tail': 'koala sanctuary'},
#  {'relation': 'use', 'head': 'raised beds', 'tail': 'cultivated'},
#  {'relation': 'part of', 'head': 'platform', 'tail': 'railway station'},
#  {'relation': 'has part', 'head': 'railway station', 'tail': 'platform'},
#  {'relation': 'part of', 'head': 'gable', 'tail': 'roof'},
#  {'relation': 'item operated', 'head': 'railway station', 'tail': 'train'},
#  {'relation': 'connecting line',
#   'head': 'train station',
#   'tail': 'train circuit'},
#  {'relation': 'terminus', 'head': 'train circuit', 'tail': 'train station'},
#  ...]

# %%
len(new_rel_list)
# Out:
# 563653

# %%
import json
with open("kb_ped_wiki_0.json", "w") as json_file:
    json.dump(new_rel_list, json_file)

# %%
# Read the JSON data from the file
with open("kb_ped_wiki_0.json", "r") as json_file:
    loaded_data_0 = json.load(json_file)

# %%
with open("kb_ped_wiki_1.json", "r") as json_file:
    loaded_data_1 = json.load(json_file)

# %%
with open("kb_ped_wiki_2.json", "r") as json_file:
    loaded_data_2 = json.load(json_file)

# %%
import copy
all_relations = copy.deepcopy(loaded_data_0)
# all_relations

# %%
def dict_to_tuple(d):
    return tuple(sorted(d.items()))

# %%
# Combine the two lists
combined_list = loaded_data_0 + loaded_data_1 + loaded_data_2

# Convert list of dictionaries to a set of tuples
unique_tuples = set(map(dict_to_tuple, combined_list))

# Convert set of tuples back to a list of dictionaries
unique_combined_list = [dict(t) for t in unique_tuples]

# %%
len(unique_combined_list)
# Out:
# 1404867

# %%
# def are_relations_equal(r1, r2):
#         return all(r1[attr] == r2[attr] for attr in ["head", "relation", "tail"])

# def exists_relation(r1):
#     return any(are_relations_equal(r1, r2) for r2 in all_relations)

# def add_relation(r):
#     if not exists_relation(r):
#         all_relations.append(r)

# %%
unique_combined_list
# Out:
# [{'head': 'Medical Payments', 'relation': 'subclass of', 'tail': 'insurance'},
#  {'head': 'Georges Couthon', 'relation': 'family', 'tail': 'Couthon'},
#  {'head': 'Hong Kong', 'relation': 'language used', 'tail': 'Chinese'},
#  {'head': 'intro', 'relation': 'has part', 'tail': 'citation-needed tag'},
#  {'head': 'Mark Taper Forum',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Los Angeles'},
#  {'head': 'Mekong', 'relation': 'basin country', 'tail': 'Cambodia'},
#  {'head': 'Jack Rabbit Racer',
#   'relation': 'end time',
#   'tail': '1930.[citation'},
#  {'head': 'Persistent vandalism',
#   'relation': 'subclass of',
#   'tail': 'disruptive edits'},
#  {'head': 'Rhineland',
#   'relation': 'dissolved, abolished or demolished date',
#   'tail': '4 December 1918'},
#  {'head': 'Filming',
#   'relation': 'start time',
#   'tail': 'September 23, 2006.[42'},
#  {'head': 'Chogha Zanbil', 'relation': 'family', 'tail': 'Zanbil'},
#  {'head': 'Annunciation', 'relation': 'has part', 'tail': "Mary's Coronation"},
#  {'head': 'Aix-en-Provence', 'relation': 'country', 'tail': 'France'},
#  {'head': 'Technical factors', 'relation': 'subclass of', 'tail': 'factors'},
#  {'head': 'Winterthur', 'relation': 'country', 'tail': 'Switzerland'},
#  {'head': 'Volvo V70 Plug-in Hybrid',
#   'relation': 'manufacturer',
#   'tail': 'Volvo Cars'},
#  {'head': 'Wikipedia', 'relation': 'instance of', 'tail': 'website'},
#  {'head': 'Mao Tse-tung',
#   'relation': 'member of political party',
#   'tail': 'Kuomintang'},
#  {'head': '2013 Pew Research poll',
#   'relation': 'point in time',
#   'tail': '2013'},
#  {'head': 'Hannover Medical School',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Hannover'},
#  {'head': 'hot air', 'relation': 'subclass of', 'tail': 'air exchange'},
#  {'head': 'structures',
#   'relation': 'subclass of',
#   'tail': 'Principal elements of cultural heritage significance'},
#  {'head': 'A41', 'relation': 'length', 'tail': '1.2'},
#  {'head': 'forklift', 'relation': 'part of', 'tail': 'warehouses'},
#  {'head': 'fourth-generation Highlander',
#   'relation': 'start time',
#   'tail': '18 December 2019'},
#  {'head': 'femurs', 'relation': 'part of', 'tail': 'legs'},
#  {'head': 'Basora',
#   'relation': 'participant in',
#   'tail': "Robinson's 50-second, first-round knockout"},
#  {'head': 'North America', 'relation': 'has part', 'tail': 'Taiwan'},
#  {'head': 'level crossing', 'relation': 'different from', 'tail': 'tunnel'},
#  {'head': '281', 'relation': 'part of', 'tail': 'London Buses'},
#  {'head': 'General Motors', 'relation': 'owner of', 'tail': 'EDR'},
#  {'head': 'Metra Electric',
#   'relation': 'connects with',
#   'tail': 'Rock Island'},
#  {'head': 'Bridge', 'relation': 'has part', 'tail': 'structural state'},
#  {'head': 'popular', 'relation': 'subclass of', 'tail': 'magazine'},
#  {'head': 'battle', 'relation': 'part of', 'tail': 'English Civil War'},
#  {'head': 'feedback', 'relation': 'part of', 'tail': 'documentation'},
#  {'head': 'Carolina Power & Light Company',
#   'relation': 'inception',
#   'tail': '1886'},
#  {'head': 'electronic', 'relation': 'has part', 'tail': 'ballasts'},
#  {'head': 'Warburton',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Warrington'},
#  {'head': 'Superb', 'relation': 'has part', 'tail': '1.9 litre TDI'},
#  {'head': 'Academic Analytics',
#   'relation': 'country',
#   'tail': 'United States'},
#  {'head': 'Station-Bus Interface',
#   'relation': 'part of',
#   'tail': 'Station Design and Station-Bus Interface'},
#  {'head': 'pitch', 'relation': 'used by', 'tail': 'busker'},
#  {'head': 'stainless steel',
#   'relation': 'different from',
#   'tail': 'aluminium'},
#  {'head': 'Jesus', 'relation': 'present in work', 'tail': 'Gospel of John'},
#  {'head': 'Augustus Caesar',
#   'relation': 'significant event',
#   'tail': 'poisoned figs'},
#  {'head': 'Manuel Baquedano',
#   'relation': 'has part',
#   'tail': 'Manuel Estiarte'},
#  {'head': 'Masonic Lodge',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Punta Gorda'},
#  {'head': 'Detective Corps', 'relation': 'part of', 'tail': 'National Police'},
#  {'head': 'separate housing',
#   'relation': 'subclass of',
#   'tail': 'designated areas'},
#  {'head': 'window tax.[8][9',
#   'relation': 'different from',
#   'tail': 'blind windows'},
#  {'head': 'state it separately',
#   'relation': 'different from',
#   'tail': "I'm not sure how to fit this in above"},
#  {'head': 'Herbert Sutcliffe',
#   'relation': 'member of',
#   'tail': 'southern amateurs'},
#  {'head': 'Coalport Bridge', 'relation': 'inception', 'tail': '1818'},
#  {'head': 'Aldrovanda vesiculosa',
#   'relation': 'parent taxon',
#   'tail': 'Aldrin'},
#  {'head': 'own line to London from Bedford,[14',
#   'relation': 'length',
#   'tail': '50'},
#  {'head': '2008', 'relation': 'location', 'tail': 'Luzhniki'},
#  {'head': 'archive', 'relation': 'has part', 'tail': 'last'},
#  {'head': 'T-bone', 'relation': 'subclass of', 'tail': 'steak'},
#  {'head': 'i-Tree', 'relation': 'instance of', 'tail': 'Modeling tools'},
#  {'head': 'Metro station',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Mitropoleos'},
#  {'head': 'Fort Connaught',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Sentosa island'},
#  {'head': 'Kobe earthquake', 'relation': 'instance of', 'tail': 'earthquake'},
#  {'head': 'piers of the bridge', 'relation': 'subclass of', 'tail': 'piers'},
#  {'head': 'Tomb Raider', 'relation': 'cast member', 'tail': 'Tomi Adeyemi'},
#  {'head': 'Clark Planetarium', 'relation': 'part of', 'tail': 'The Gateway'},
#  {'head': '1965 World Series', 'relation': 'point in time', 'tail': '1965'},
#  {'head': 'London Paddington.[106',
#   'relation': 'instance of',
#   'tail': 'all-electric'},
#  {'head': 'Branko Pešić',
#   'relation': 'position held',
#   'tail': 'mayor of Belgrade'},
#  {'head': 'Ashmont–Mattapan Line',
#   'relation': 'date of official opening',
#   'tail': 'December 1847'},
#  {'head': 'interior designers',
#   'relation': 'field of this occupation',
#   'tail': 'design professionals'},
#  {'head': 'Montrose Bamse Project',
#   'relation': 'has part',
#   'tail': 'Angus Whitson'},
#  {'head': 'transplanted population',
#   'relation': 'replaces',
#   'tail': 'expelled population'},
#  {'head': 'noise abatement', 'relation': 'facet of', 'tail': 'Noise'},
#  {'head': 'Nick', 'relation': 'instance of', 'tail': 'invisible man'},
#  {'head': 'Reference 28',
#   'relation': 'part of',
#   'tail': 'Encyclopedia Britannica'},
#  {'head': 'Kwun Tong.[82][83',
#   'relation': 'shares border with',
#   'tail': 'Tai Po'},
#  {'head': 'Latino', 'relation': 'instance of', 'tail': 'race'},
#  {'head': 'tap water', 'relation': 'country', 'tail': 'Norwegian'},
#  {'head': 'Ryu', 'relation': 'owner of', 'tail': 'android companion'},
#  {'head': 'Norwegian Railway Club',
#   'relation': 'owner of',
#   'tail': 'Garnes Station'},
#  {'head': 'search box', 'relation': 'uses', 'tail': 'URL'},
#  {'head': 'police force',
#   'relation': 'applies to jurisdiction',
#   'tail': 'Detroit'},
#  {'head': 'religious', 'relation': 'different from', 'tail': 'ethnic'},
#  {'head': '1992 Summer Olympics', 'relation': 'point in time', 'tail': '1992'},
#  {'head': 'porthole-like window', 'relation': 'subclass of', 'tail': 'window'},
#  {'head': 'junction', 'relation': 'part of', 'tail': 'Seven Corners'},
#  {'head': 'Block 37 station', 'relation': 'owned by', 'tail': 'CTA'},
#  {'head': 'Germany', 'relation': 'diplomatic relation', 'tail': 'Denmark'},
#  {'head': 'A302 Westminster Bridge',
#   'relation': 'connects with',
#   'tail': 'A23 Westminster Bridge Road'},
#  {'head': 'Raul Estuardo Lorenzana',
#   'relation': 'spouse',
#   'tail': 'Ines Mufio Padilla'},
#  {'head': 'Mazovian Railroads', 'relation': 'connects with', 'tail': 'WKD'},
#  {'head': 'Stripped', 'relation': 'performer', 'tail': 'Christina Aguilera'},
#  {'head': 'Elmhurst',
#   'relation': 'shares border with',
#   'tail': 'Middle Village'},
#  {'head': 'March 1918 genocide',
#   'relation': 'point in time',
#   'tail': 'March 1918'},
#  {'head': 'sequence', 'relation': 'different from', 'tail': 'transitions'},
#  {'head': 'Ayd Mill Road',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Saint Paul, Minnesota'},
#  {'head': 'quarry',
#   'relation': 'product or material produced',
#   'tail': 'brownstone'},
#  {'head': 'C major.[7', 'relation': 'instance of', 'tail': 'key'},
#  {'head': 'rubber slider', 'relation': 'subclass of', 'tail': 'pendulum'},
#  {'head': 'skateboarders',
#   'relation': 'field of this occupation',
#   'tail': 'Skateboarding'},
#  {'head': 'Caracas Boys',
#   'relation': 'country of origin',
#   'tail': 'Venezuelan'},
#  {'head': 'Sarastro1 (talk)',
#   'relation': 'publication date',
#   'tail': '24 March 2017'},
#  {'head': 'Brown Bomber', 'relation': 'home venue', 'tail': 'Yankee Stadium'},
#  {'head': 'Norman', 'relation': 'said to be the same as', 'tail': 'French'},
#  {'head': 'Caribbean', 'relation': 'subclass of', 'tail': 'Afro'},
#  {'head': 'brake pressure sensors',
#   'relation': 'subclass of',
#   'tail': 'sensors'},
#  {'head': 'Sherenk1 (talk)',
#   'relation': 'part of',
#   'tail': "Nominator's comments"},
#  {'head': 'Cheers, Peacemaker67',
#   'relation': 'point in time',
#   'tail': '7 January 2022'},
#  {'head': 'Macintosh Run', 'relation': 'tributary', 'tail': 'Jordan Creek'},
#  {'head': 'Northallerton', 'relation': 'connecting line', 'tail': 'main line'},
#  {'head': 'dash', 'relation': 'instance of', 'tail': 'punctuation marks'},
#  {'head': 'Penn Station',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Newark'},
#  {'head': 'Last Week Tonight', 'relation': 'follows', 'tail': 'experiment'},
#  {'head': 'Super Mario 64 DS', 'relation': 'platform', 'tail': 'Nintendo DS'},
#  {'head': 'Alice Street',
#   'relation': 'connects with',
#   'tail': 'Margaret Street'},
#  {'head': '--Nasty Housecat (talk)',
#   'relation': 'publication date',
#   'tail': '11 August 2010'},
#  {'head': 'Elizabeth, New Jersey',
#   'relation': 'shares border with',
#   'tail': 'Staten Island, New York'},
#  {'head': 'Shanghainese',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Shanghai'},
#  {'head': 'Waterfront', 'relation': 'owned by', 'tail': 'MBTA'},
#  {'head': 'Scamander Post Office',
#   'relation': 'dissolved, abolished or demolished date',
#   'tail': '1933'},
#  {'head': 'Knoxville, Tennessee',
#   'relation': 'twinned administrative body',
#   'tail': 'Nashville, Tennessee'},
#  {'head': 'XLIV', 'relation': 'has part', 'tail': 'CHAPTER XLIV'},
#  {'head': 'density', 'relation': 'part of', 'tail': 'shape'},
#  {'head': 'EveryBody Rides', 'relation': 'inception', 'tail': '2014'},
#  {'head': 'White River Greenway',
#   'relation': 'connects with',
#   'tail': 'Cardinal Greenway'},
#  {'head': 'class A.', 'relation': 'has part', 'tail': 'A.'},
#  {'head': 'common',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Sydney'},
#  {'head': 'Varnbüler', 'relation': 'position held', 'tail': 'mayor'},
#  {'head': 'rule', 'relation': 'has part', 'tail': 'actually saying'},
#  {'head': 'Penarth Pier',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Penarth'},
#  {'head': 'Barry Docks',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Vale of Glamorgan'},
#  {'head': 'Manhattan Beach Unified School district',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'California.[when?][citation'},
#  {'head': 'http://paleofuture.gizmodo.com/the-man-who-fought-cults-and-won-1634267961',
#   'relation': 'has part',
#   'tail': 'Synanon'},
#  {'head': 'Physics', 'relation': 'instance of', 'tail': 'science'},
#  {'head': 'ds^{2}=\\delta',
#   'relation': 'said to be the same as',
#   'tail': 'ds^{2}=\\delta'},
#  {'head': 'glass roof', 'relation': 'part of', 'tail': 'station'},
#  {'head': 'NBC', 'relation': 'instance of', 'tail': 'broadcast network'},
#  {'head': 'Downtown Connector', 'relation': 'connects with', 'tail': 'I-75'},
#  {'head': 'radio networks', 'relation': 'uses', 'tail': 'radio protocol'},
#  {'head': 'wrist', 'relation': 'connects with', 'tail': 'ankle'},
#  {'head': 'Hitler', 'relation': 'military branch', 'tail': 'Army'},
#  {'head': 'Leng Kee Road',
#   'relation': 'connects with',
#   'tail': 'Alexandra Road'},
#  {'head': 'season finale', 'relation': 'season', 'tail': '41st season'},
#  {'head': 'economic hardships.[35', 'relation': 'country', 'tail': 'Burmese'},
#  {'head': 'John Robert Cozens',
#   'relation': 'sibling',
#   'tail': 'Alexander Cozens'},
#  {'head': 'paths', 'relation': 'different from', 'tail': 'roads'},
#  {'head': 'intelligence issues',
#   'relation': 'facet of',
#   'tail': 'national security'},
#  {'head': 'bike lanes', 'relation': 'subclass of', 'tail': 'bike paths'},
#  {'head': 'senators', 'relation': 'opposite of', 'tail': 'representative'},
#  {'head': 'one of the other colleges',
#   'relation': 'part of',
#   'tail': 'Claremont Colleges'},
#  {'head': 'La Maddalena', 'relation': 'industry', 'tail': 'tourism'},
#  {'head': 'National Register of Historic Places',
#   'relation': 'inception',
#   'tail': '1985.[7'},
#  {'head': 'Etobicoke York',
#   'relation': 'instance of',
#   'tail': 'service districts'},
#  {'head': 'number of trains that can cross the junction',
#   'relation': 'has effect',
#   'tail': 'train backups'},
#  {'head': 'Alaska', 'relation': 'inception', 'tail': '1959'},
#  {'head': 'Richard de Trafford', 'relation': 'owner of', 'tail': 'Stretford'},
#  {'head': 'south', 'relation': 'connects with', 'tail': 'north'},
#  {'head': 'Jubilee', 'relation': 'connects with', 'tail': 'District'},
#  {'head': 'steppe.\n', 'relation': 'follows', 'tail': 'exurbs several'},
#  {'head': 'maze', 'relation': 'said to be the same as', 'tail': 'labyrinth'},
#  {'head': '13.8%', 'relation': 'subclass of', 'tail': 'population'},
#  {'head': 'Raichu', 'relation': 'publication date', 'tail': '3 June 2006'},
#  {'head': 'taxi', 'relation': 'has part', 'tail': 'taxi stand'},
#  {'head': 'prisoners', 'relation': 'has part', 'tail': 'guards'},
#  {'head': 'dentist',
#   'relation': 'field of this occupation',
#   'tail': 'dental care'},
#  {'head': 'Grand i10', 'relation': 'start time', 'tail': '16 July 2020'},
#  {'head': 'robotics', 'relation': 'subclass of', 'tail': 'high tech'},
#  {'head': 'Midrise Hall)[14', 'relation': 'instance of', 'tail': 'dormitory'},
#  {'head': 'Morgunblaðið', 'relation': 'instance of', 'tail': 'newspaper'},
#  {'head': 'Buff Bay station', 'relation': 'country', 'tail': 'Jamaica'},
#  {'head': 'stressor', 'relation': 'has cause', 'tail': 'cleaning'},
#  {'head': 'Political views', 'relation': 'part of', 'tail': 'Economic views'},
#  {'head': 'Mackay and Blackstock',
#   'relation': 'inception',
#   'tail': '7 August 1847'},
#  {'head': 'swart',
#   'relation': 'language of work or name',
#   'tail': 'Middle English'},
#  {'head': 'Anarchist Free Space',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Kensington Market'},
#  {'head': 'sparsely populated', 'relation': 'is a list of', 'tail': 'canton'},
#  {'head': 'National Commercial Bank',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Jeddah'},
#  {'head': 'search engine', 'relation': 'subclass of', 'tail': 'specialized'},
#  {'head': 'New Zealand', 'relation': 'diplomatic relation', 'tail': 'Canada'},
#  {'head': 'different types of paths',
#   'relation': 'part of',
#   'tail': 'Central Park'},
#  {'head': 'front splitter',
#   'relation': 'part of',
#   'tail': 'aerodynamic package'},
#  {'head': 'The Wild One', 'relation': 'cast member', 'tail': 'Marlon Brando'},
#  {'head': 'Maiden of Black Water',
#   'relation': 'narrative location',
#   'tail': 'Hikami Mountain'},
#  {'head': 'use of nuclear weapons.[332][333][334',
#   'relation': 'subclass of',
#   'tail': 'threatened'},
#  {'head': 'Spor Salonu', 'relation': 'shares border with', 'tail': 'Bağcılar'},
#  {'head': 'Flexity Classic', 'relation': 'subclass of', 'tail': 'trams'},
#  {'head': 'largest operational double-decker tram fleet',
#   'relation': 'product or material produced',
#   'tail': 'tram'},
#  {'head': 'first season',
#   'relation': 'original broadcaster',
#   'tail': 'Netflix.[2'},
#  {'head': 'East Coast Main Line',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Tyneside'},
#  {'head': 'ColonialGrid (talk)',
#   'relation': 'inception',
#   'tail': '28 February 2015'},
#  {'head': 'Veil of Trees',
#   'relation': 'followed by',
#   'tail': 'Into the Trees II'},
#  {'head': 'Wayla',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Toronto'},
#  {'head': 'Promenade Concerts', 'relation': 'end time', 'tail': '1914'},
#  {'head': 'Ragged Staff Cave', 'relation': 'instance of', 'tail': 'magazine'},
#  {'head': 'University of Oxford',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'England'},
#  {'head': 'Poland', 'relation': 'shares border with', 'tail': 'Denmark'},
#  {'head': 'air defence identification zones',
#   'relation': 'part of',
#   'tail': 'airspace'},
#  {'head': 'Fort Wilderness Railroad',
#   'relation': 'instance of',
#   'tail': 'heritage railroad'},
#  {'head': 'Victorian', 'relation': 'shares border with', 'tail': 'Australian'},
#  {'head': 'Jorge Salinas',
#   'relation': 'spouse',
#   'tail': 'Ana Brenda Contreras'},
#  {'head': 'Gion Matsuri',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Matsuri'},
#  {'head': 'Arizona',
#   'relation': 'located in or next to body of water',
#   'tail': 'river'},
#  {'head': 'kerbs', 'relation': 'part of', 'tail': 'traffic islands'},
#  {'head': 'Mission Dolores',
#   'relation': 'located in or next to body of water',
#   'tail': 'Yerba Buena Cove'},
#  {'head': 'different way of thinking',
#   'relation': 'facet of',
#   'tail': 'chimpanzee'},
#  {'head': 'puttting', 'relation': 'uses', 'tail': 'puttting'},
#  {'head': 'UCSC', 'relation': 'has part', 'tail': 'McHenry Library.[110][111'},
#  {'head': 'Man on the Moon',
#   'relation': 'followed by',
#   'tail': 'Man on the Moon II: The Legend of Mr. Rager'},
#  {'head': 'Mechanics Institute', 'relation': 'inception', 'tail': '1885'},
#  {'head': 'five traffic signals', 'relation': 'part of', 'tail': 'I-180'},
#  {'head': 'Inner Ring Road',
#   'relation': 'instance of',
#   'tail': 'pedestrian subways'},
#  {'head': 'Washington', 'relation': 'instance of', 'tail': 'quarter'},
#  {'head': 'crater', 'relation': 'part of', 'tail': 'embankment'},
#  {'head': 'U.S.', 'relation': 'subclass of', 'tail': 'television'},
#  {'head': 'roofline', 'relation': 'has part', 'tail': 'skylights'},
#  {'head': 'conjecture', 'relation': 'opposite of', 'tail': 'uncited'},
#  {'head': 'Newark', 'relation': 'twinned administrative body', 'tail': 'JFK'},
#  {'head': 'gallop.[5', 'relation': 'subclass of', 'tail': 'gaits'},
#  {'head': 'retail',
#   'relation': 'instance of',
#   'tail': 'economic sectors in Berlin'},
#  {'head': '91 Street',
#   'relation': 'connects with',
#   'tail': 'Gateway Boulevard'},
#  {'head': 'Lobatse',
#   'relation': 'twinned administrative body',
#   'tail': 'Gaberones'},
#  {'head': 'Malaysian parliament', 'relation': 'country', 'tail': 'Malaysia'},
#  {'head': 'fanboy',
#   'relation': 'said to be the same as',
#   'tail': 'bit of a fanboy'},
#  {'head': 'taken in a certain amount',
#   'relation': 'said to be the same as',
#   'tail': 'medication'},
#  {'head': 'bails', 'relation': 'connects with', 'tail': 'stumps'},
#  {'head': 'Greater Los Angeles',
#   'relation': 'located in or next to body of water',
#   'tail': 'Los Angeles River'},
#  {'head': 'fairy tales',
#   'relation': 'subclass of',
#   'tail': 'lull themselves to sleep'},
#  {'head': 'Florida Canyon',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'San Diego'},
#  {'head': 'Terrace', 'relation': 'different from', 'tail': 'Terrace'},
#  {'head': '--Abductive (reasoning)',
#   'relation': 'instance of',
#   'tail': 'reasoning'},
#  {'head': 'Cuba Street',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Wellington'},
#  {'head': 'Columbia',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Wisconsin'},
#  {'head': 'motorcycling', 'relation': 'uses', 'tail': 'motorcycle'},
#  {'head': 'Foxtrot', 'relation': 'genre', 'tail': 'progressive rock'},
#  {'head': '{{Millennium Park}}',
#   'relation': 'different from',
#   'tail': 'Millennium Park'},
#  {'head': 'MBTA', 'relation': 'has part', 'tail': 'board'},
#  {'head': 'Owl',
#   'relation': 'date of official opening',
#   'tail': 'June 15, 2019'},
#  {'head': 'Malcolm Shabazz City High School',
#   'relation': 'instance of',
#   'tail': 'public high schools'},
#  {'head': 'Guinea,[64', 'relation': 'diplomatic relation', 'tail': 'Ghana'},
#  {'head': 'Frank Benson.[70',
#   'relation': 'occupation',
#   'tail': 'actor/manager'},
#  {'head': 'Albert Einstein', 'relation': 'field of work', 'tail': 'Physicist'},
#  {'head': 'R1', 'relation': 'part of', 'tail': 'European Cycle Route'},
#  {'head': 'http://french.about.com/od/grammar/ss/subjectpronouns_3.htm',
#   'relation': 'part of',
#   'tail': 'http://french.about.com/od/grammar/ss/subjectpronouns_3.htm'},
#  {'head': 'Bx20MTA', 'relation': 'operator', 'tail': 'NYC Bus'},
#  {'head': 'may say to you',
#   'relation': 'different from',
#   'tail': 'sometimes says to you'},
#  {'head': 'criminology', 'relation': 'has part', 'tail': 'sociology of crime'},
#  {'head': 'British and Irish',
#   'relation': 'part of',
#   'tail': 'Continental Europe'},
#  {'head': 'rheic', 'relation': 'different from', 'tail': 'acidic'},
#  {'head': 'Centric', 'relation': 'instance of', 'tail': 'student magazine'},
#  {'head': 'Peter',
#   'relation': 'has works in the collection',
#   'tail': 'Metropolitan Museum of Art'},
#  {'head': 'Metropolitan Opera',
#   'relation': 'headquarters location',
#   'tail': 'Rockefeller Center'},
#  {'head': 'Selected lead/1',
#   'relation': 'number of participants',
#   'tail': 'lead/1'},
#  {'head': 'Wiesbaden',
#   'relation': 'contains administrative territorial entity',
#   'tail': 'Kastel'},
#  {'head': 'FKOHT).[13',
#   'relation': 'has parts of the class',
#   'tail': 'bicycle and jogging paths'},
#  {'head': '8th Avenue entrance', 'relation': 'part of', 'tail': '8th Avenue'},
#  {'head': 'SUN-InBev', 'relation': 'subsidiary', 'tail': 'Tinkoff'},
#  {'head': 'Wilson', 'relation': 'instance of', 'tail': 'label'},
#  {'head': 'transport planning',
#   'relation': 'different from',
#   'tail': 'land use planning'},
#  {'head': 'gangster', 'relation': 'opposite of', 'tail': 'bad guys'},
#  {'head': 'copy editing', 'relation': 'has part', 'tail': 'comments'},
#  {'head': 'diabetes',
#   'relation': 'different from',
#   'tail': 'nothing to do with diabetes'},
#  {'head': 'Facade at 57',
#   'relation': 'elevation above sea level',
#   'tail': '57'},
#  {'head': 'head station',
#   'relation': 'connecting line',
#   'tail': 'rapid-transit railway node for pedestrians'},
#  {'head': 'FICT', 'relation': 'practiced by', 'tail': 'editor'},
#  {'head': 'JavaScript',
#   'relation': 'instance of',
#   'tail': 'application programming interface.[24'},
#  {'head': 'Ben Nelson', 'relation': 'position held', 'tail': 'Governor'},
#  {'head': 'Aretha Franklin', 'relation': 'record label', 'tail': 'Motown'},
#  {'head': 'massacre of white people by Native Americans',
#   'relation': 'participant',
#   'tail': 'white people'},
#  {'head': 'stop and go', 'relation': 'facet of', 'tail': 'traffic'},
#  {'head': 'Santa Cruz das Flores', 'relation': 'inception', 'tail': '1814'},
#  {'head': 'slums', 'relation': 'location', 'tail': 'inner-city'},
#  {'head': 'Bridge', 'relation': 'different from', 'tail': 'Railroad Bridge'},
#  {'head': 'union building',
#   'relation': 'different from',
#   'tail': 'main union building'},
#  {'head': 'Galactose', 'relation': 'has part', 'tail': 'Galago'},
#  {'head': 'La Grande Illusion', 'relation': 'league', 'tail': 'La Liga'},
#  {'head': 'Stefan Kudelski', 'relation': 'child', 'tail': 'André Kudelski'},
#  {'head': 'Lloyd Cunningham',
#   'relation': 'field of work',
#   'tail': 'forensic document examiner'},
#  {'head': 'Australia', 'relation': 'sport', 'tail': 'T20 cricket'},
#  {'head': 'Royal Danish Arsenal Museum',
#   'relation': 'named after',
#   'tail': 'Christian IV'},
#  {'head': 'corduroy gate', 'relation': 'subclass of', 'tail': 'auto gate'},
#  {'head': 'N⋅m', 'relation': 'different from', 'tail': 'N⋅m'},
#  {'head': 'two months',
#   'relation': 'followed by',
#   'tail': 'Over two months old'},
#  {'head': 'Ron Paul',
#   'relation': 'candidacy in election',
#   'tail': 'bid for the presidency.[57'},
#  {'head': 'Albert Cotter bridge',
#   'relation': 'named after',
#   'tail': 'Albert Cotter'},
#  {'head': 'basketball', 'relation': 'sport', 'tail': 'soccer'},
#  {'head': 'National Coastal Zone Management Authority".[8',
#   'relation': 'parent organization',
#   'tail': 'NCZMA'},
#  {'head': 'North Shore', 'relation': 'connects with', 'tail': 'Northern'},
#  {'head': 'fixed-route system.[17',
#   'relation': 'subclass of',
#   'tail': 'Door-to-door service'},
#  {'head': 'A ribbon-cutting ceremony',
#   'relation': 'point in time',
#   'tail': 'March 22, 2012'},
#  {'head': 'Hindustani', 'relation': 'different from', 'tail': 'Farsi'},
#  {'head': 'Queens Boulevard subway line',
#   'relation': 'named after',
#   'tail': 'Queens Boulevard'},
#  {'head': 'church weather vane', 'relation': 'depicts', 'tail': 'fiddle'},
#  {'head': 'Puget Sound',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Washington State'},
#  {'head': 'Chernovetskyi Charity Fund.[62',
#   'relation': 'founded by',
#   'tail': 'Leonid Chernovetskyi'},
#  {'head': 'Van Dyke', 'relation': 'instance of', 'tail': 'complaints'},
#  {'head': 'Lime Street station',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Edge Hill'},
#  {'head': 'vineyards and wineries on Waiheke Island',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Waiheke Island'},
#  {'head': 'Chloethiel Woodard Smith',
#   'relation': 'movement',
#   'tail': 'Modernist movement'},
#  {'head': 'data biases', 'relation': 'facet of', 'tail': 'Machine learning'},
#  {'head': 'Mincham', 'relation': 'has part', 'tail': 'double links'},
#  {'head': 'defibrillators',
#   'relation': 'subclass of',
#   'tail': 'medical equipment'},
#  {'head': 'Angel site', 'relation': 'inception', 'tail': '1000'},
#  {'head': 'apse',
#   'relation': 'part of',
#   'tail': 'The third and uppermost level of the stage'},
#  {'head': 'Hearts, Minds and Paws',
#   'relation': 'author',
#   'tail': 'Nina Bondarenko'},
#  {'head': 'California Speedway',
#   'relation': 'country',
#   'tail': 'United States.[3'},
#  {'head': 'Mahosot Hospital',
#   'relation': 'located in or next to body of water',
#   'tail': 'river'},
#  {'head': 'Lukács László', 'relation': 'inception', 'tail': '1898'},
#  {'head': "You Can't Take It with You",
#   'relation': 'performer',
#   'tail': 'Yottabit'},
#  {'head': '1911', 'relation': 'point in time', 'tail': 'January 3, 1911'},
#  {'head': 'early development', 'relation': 'facet of', 'tail': 'city'},
#  {'head': 'same site',
#   'relation': 'has part',
#   'tail': 'second of two bridges'},
#  {'head': 'Berlin',
#   'relation': 'contains administrative territorial entity',
#   'tail': 'Berlin Alexanderplatz'},
#  {'head': 'Les Halles',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Arcis'},
#  {'head': 'business section',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'city'},
#  {'head': 'the Powerhouse Museum.[62',
#   'relation': 'part of',
#   'tail': 'Powerhouse Museum.[62'},
#  {'head': 'nationalist', 'relation': 'has part', 'tail': 'unionist'},
#  {'head': 'Attached KML', 'relation': 'owned by', 'tail': 'Google'},
#  {'head': 'Croton Yards', 'relation': 'part of', 'tail': 'Fare Zone 5-6'},
#  {'head': 'anchorage rod', 'relation': 'connects with', 'tail': 'sleeve nuts'},
#  {'head': 'Tujunga', 'relation': 'shares border with', 'tail': 'Magnolia'},
#  {'head': 'Electric Personal Assistive Mobility Devices',
#   'relation': 'applies to jurisdiction',
#   'tail': 'Georgia'},
#  {'head': 'road',
#   'relation': 'has parts of the class',
#   'tail': 'carriageways'},
#  {'head': 'DefThree (talk)',
#   'relation': 'date of death',
#   'tail': '5 November 2022'},
#  {'head': 'Beavermead Campground',
#   'relation': 'instance of',
#   'tail': 'campsites'},
#  {'head': 'Incontro Industrial Park',
#   'relation': 'industry',
#   'tail': 'construction companies'},
#  {'head': 'sources listed', 'relation': 'part of', 'tail': 'school'},
#  {'head': 'John Paul II',
#   'relation': 'position held',
#   'tail': 'episcopal consecration'},
#  {'head': "Ryder's ransom", 'relation': 'participant', 'tail': 'mayor'},
#  {'head': 'top', 'relation': 'opposite of', 'tail': 'side'},
#  {'head': 'Asian Hercules II,[44',
#   'relation': 'instance of',
#   'tail': 'floating cranes'},
#  {'head': 'Downtown Halifax',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Halifax'},
#  {'head': 'emergency maneuvers', 'relation': 'uses', 'tail': 'paved surface'},
#  {'head': 'William Clark',
#   'relation': 'participant in',
#   'tail': 'expedition across America'},
#  {'head': 'M102', 'relation': 'connects with', 'tail': 'M98'},
#  {'head': 'congenital rubella syndrome',
#   'relation': 'subclass of',
#   'tail': 'conditions related to pregnancy'},
#  {'head': 'Moorgate', 'relation': 'inception', 'tail': '1672'},
#  {'head': 'Key Bridge',
#   'relation': 'located on terrain feature',
#   'tail': 'Columbia Island'},
#  {'head': 'Corolla Cross Hybrid S/SE/XSE',
#   'relation': 'part of the series',
#   'tail': 'Corolla Cross'},
#  {'head': 'Altered walking', 'relation': 'facet of', 'tail': 'walking'},
#  {'head': 'mopeds', 'relation': 'different from', 'tail': 'small motorcycles'},
#  {'head': 'playable', 'relation': 'subclass of', 'tail': 'scenarios'},
#  {'head': 'PlayStation 3', 'relation': 'country', 'tail': 'Japanese'},
#  {'head': 'Boeing 737', 'relation': 'subclass of', 'tail': 'aircraft'},
#  {'head': 'Norfolk Botanical Garden', 'relation': 'inception', 'tail': '1939'},
#  {'head': 'Radburn', 'relation': 'shares border with', 'tail': 'Reston'},
#  {'head': 'CIRCA',
#   'relation': 'located on street',
#   'tail': 'Piccadilly Circus.[44'},
#  {'head': 'Lou Reed', 'relation': 'occupation', 'tail': 'band leader'},
#  {'head': 'Venice Boulevard',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Los Angeles'},
#  {'head': 'artificial intelligence',
#   'relation': 'uses',
#   'tail': 'natural language'},
#  {'head': 'Emotient.[224',
#   'relation': 'parent organization',
#   'tail': 'Apple Inc.'},
#  {'head': 'swarm', 'relation': 'different from', 'tail': 'Swarming'},
#  {'head': 'actionable', 'relation': 'opposite of', 'tail': 'invalid'},
#  {'head': 'terminus', 'relation': 'part of', 'tail': 'trail'},
#  {'head': 'Duke Gardens', 'relation': 'founded by', 'tail': 'Doris Duke,[52'},
#  {'head': 'capital cities', 'relation': 'country', 'tail': 'Australian'},
#  {'head': 'downpours', 'relation': 'part of', 'tail': 'thunderstorms'},
#  {'head': 'Houston Chronicle',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Houston'},
#  {'head': 'William John Mitchell', 'relation': 'employer', 'tail': 'MIT'},
#  {'head': 'A2Z', 'relation': 'has part', 'tail': 'Channel 11'},
#  {'head': 'Union Station',
#   'relation': 'architect',
#   'tail': 'Woollen, Molzan and Partners'},
#  {'head': 'U.S. Treasury', 'relation': 'country', 'tail': 'U.S.'},
#  {'head': 'The Morning Call Plaza Tropical',
#   'relation': 'has part',
#   'tail': 'Munelly'},
#  {'head': 'painting', 'relation': 'subclass of', 'tail': 'art'},
#  {'head': 'Rockbank', 'relation': 'shares border with', 'tail': 'Melton'},
#  {'head': 'Holland Landing',
#   'relation': 'shares border with',
#   'tail': 'Yonge Street'},
#  {'head': 'John Andretti', 'relation': 'sport', 'tail': 'NASCAR'},
#  {'head': 'psychoanalyst', 'relation': 'studies', 'tail': 'compassion'},
#  {'head': 'glass boxes',
#   'relation': 'subclass of',
#   'tail': 'architectural statement'},
#  {'head': 'Traffic sign design',
#   'relation': 'facet of',
#   'tail': 'traffic signage'},
#  {'head': 'Tesla, Inc.', 'relation': 'subsidiary', 'tail': 'NUMMI'},
#  {'head': 'wildlife', 'relation': 'has part', 'tail': 'animals'},
#  {'head': 'Eastshore Freeway',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Oakland'},
#  {'head': 'Esplanade Hotel', 'relation': 'inception', 'tail': '1887'},
#  {'head': 'Le Mans',
#   'relation': 'twinned administrative body',
#   'tail': 'Saint-Georges-du-Bois'},
#  {'head': 'Croatian Parliament',
#   'relation': 'located on street',
#   'tail': "St. Mark's Square"},
#  {'head': 'Krejcárek', 'relation': 'shares border with', 'tail': 'Modřany'},
#  {'head': 'Giulio Cesare Colonna di Sciarra',
#   'relation': 'family',
#   'tail': 'Barberini Colonna di Sciara'},
#  {'head': 'Jerry Pinkney',
#   'relation': 'place of birth',
#   'tail': 'Croton-on-Hudson, New York'},
#  {'head': 'Ough', 'relation': 'followed by', 'tail': 'out'},
#  {'head': 'Beach', 'relation': 'instance of', 'tail': 'natural ridge'},
#  {'head': 'Z07x10 (talk)',
#   'relation': 'publication date',
#   'tail': '22 September 2013'},
#  {'head': 'Boissière (talk)',
#   'relation': 'publication date',
#   'tail': '19 September 2008'},
#  {'head': 'Kentish Town Lock', 'relation': 'instance of', 'tail': 'Lock'},
#  {'head': 'Maya Angelou', 'relation': 'spouse', 'tail': 'May Wirth'},
#  {'head': 'Liberty Head nickel',
#   'relation': 'start time',
#   'tail': '17 year life'},
#  {'head': 'animals', 'relation': 'studied by', 'tail': 'Veterinarian'},
#  {'head': "President's Park", 'relation': 'has part', 'tail': 'White House'},
#  {'head': 'SR 35', 'relation': 'connects with', 'tail': 'US 17'},
#  {'head': 'Queen Victoria', 'relation': 'spouse', 'tail': 'her husband'},
#  {'head': 'Carrillo Adobe',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Santa Rosa'},
#  {'head': 'KMXF', 'relation': 'radio format', 'tail': 'classic rock'},
#  {'head': 'Article 12 of the ICCPR', 'relation': 'part of', 'tail': 'ICCPR'},
#  {'head': 'Turtle Pond',
#   'relation': 'mouth of the watercourse',
#   'tail': 'Great Lawn'},
#  {'head': 'National Theatre', 'relation': 'architect', 'tail': 'Denys Lasdun'},
#  {'head': 'awning', 'relation': 'connects with', 'tail': 'the stair'},
#  {'head': 'Bologna–Ferrara section',
#   'relation': 'part of',
#   'tail': 'Padua–Bologna railway.[1'},
#  {'head': 'Townley Road', 'relation': 'connects with', 'tail': 'Broadway'},
#  {'head': 'forest', 'relation': 'subclass of', 'tail': 'habitat'},
#  {'head': "Colorado '88.[42", 'relation': 'publication date', 'tail': '2006'},
#  {'head': 'history', 'relation': 'facet of', 'tail': 'Boston University'},
#  {'head': 'services may be infrequent',
#   'relation': 'part of',
#   'tail': 'public transport'},
#  {'head': "2009 owner's standings",
#   'relation': 'point in time',
#   'tail': '2009'},
#  {'head': 'Robert "Bob" Belcher, Jr.',
#   'relation': 'performer',
#   'tail': 'H. Jon Benjamin'},
#  {'head': 'Kashmere Gate',
#   'relation': 'dissolved, abolished or demolished date',
#   'tail': '1965'},
#  {'head': 'Mitchel Forman', 'relation': 'work period (start)', 'tail': '1978'},
#  {'head': 'Laredo', 'relation': 'based on', 'tail': 'The Virginian'},
#  {'head': 'congestion', 'relation': 'subclass of', 'tail': 'traffic'},
#  {'head': 'Palacio de Linares',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Recoletos'},
#  {'head': 'Mikhlaf Sanaʽa', 'relation': 'instance of', 'tail': 'Makhalifs'},
#  {'head': 'HomeBase', 'relation': 'parent organization', 'tail': 'Target'},
#  {'head': 'cottage ornée', 'relation': 'subclass of', 'tail': 'cottage'},
#  {'head': 'train shed', 'relation': 'has part', 'tail': 'porte-cochère'},
#  {'head': 'Sword of Light', 'relation': 'publication date', 'tail': '1976'},
#  {'head': 'Touched', 'relation': 'facet of', 'tail': 'goodness'},
#  {'head': 'National Governors Association',
#   'relation': 'office held by head of the organization',
#   'tail': 'vice chair'},
#  {'head': 'Dubai International Motor Show.[20',
#   'relation': 'point in time',
#   'tail': '2009'},
#  {'head': 'Zwijndrecht', 'relation': 'country', 'tail': 'Belgium'},
#  {'head': 'Rush Brook Reservoir', 'relation': 'length', 'tail': '2.88'},
#  {'head': 'braking', 'relation': 'has effect', 'tail': 'collisions'},
#  {'head': 'Arques-la-Bataille',
#   'relation': 'twinned administrative body',
#   'tail': 'Quickborn'},
#  {'head': 'Woodstock Willie,[48',
#   'relation': 'instance of',
#   'tail': 'Groundhog'},
#  {'head': 'Beaux-Arts Hurlbut Memorial Gate',
#   'relation': 'location',
#   'tail': 'Waterworks Park.[54'},
#  {'head': 'philosophy',
#   'relation': 'different from',
#   'tail': 'rational enquiry'},
#  {'head': 'John Marshall',
#   'relation': 'spouse',
#   'tail': 'Edward Perry Warren'},
#  {'head': 'the original',
#   'relation': 'derivative work',
#   'tail': 'Music differed from the original'},
#  {'head': '1994 Sunshines Restaurant',
#   'relation': 'point in time',
#   'tail': '1994'},
#  {'head': 'Broomfield',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Chelmsford Rural District'},
#  {'head': 'I-205', 'relation': 'inception', 'tail': '1967'},
#  {'head': 'cross', 'relation': 'different from', 'tail': 'jaywalk'},
#  {'head': 'passed laws related to distracted driving.[45',
#   'relation': 'applies to jurisdiction',
#   'tail': 'District of Columbia'},
#  {'head': 'low incidence of violent crime',
#   'relation': 'has part',
#   'tail': 'threat of pickpockets'},
#  {'head': 'rivers', 'relation': 'subclass of', 'tail': 'freshwater'},
#  {'head': 'elevated section',
#   'relation': 'has part',
#   'tail': 'West 72nd Street'},
#  {'head': 'Paris experienced protests',
#   'relation': 'has part',
#   'tail': 'fourth consecutive week'},
#  {'head': 'Chermside Drive-In Shopping Centre',
#   'relation': 'country',
#   'tail': 'Australia'},
#  {'head': 'downtown area',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'downtown'},
#  {'head': 'face detection',
#   'relation': 'subclass of',
#   'tail': 'computer vision'},
#  {'head': 'Republic Monument',
#   'relation': 'creator',
#   'tail': 'Pietro Canonica'},
#  {'head': 'Higher Education', 'relation': 'subclass of', 'tail': 'Education'},
#  {'head': 'Lime Street Wirral Line station',
#   'relation': 'operator',
#   'tail': 'Merseyrail'},
#  {'head': 'gymnasium', 'relation': 'part of', 'tail': "Principal's Residence"},
#  {'head': 'Setha M. Low', 'relation': 'occupation', 'tail': 'anthropologist'},
#  {'head': '1924 city plan', 'relation': 'point in time', 'tail': '1924'},
#  {'head': 'New General Traction Company',
#   'relation': 'inception',
#   'tail': '1896'},
#  {'head': 'Dactylius', 'relation': 'has part', 'tail': 'the Green'},
#  {'head': 'Hampden Bridge',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'New South Wales'},
#  {'head': 'Greg Richards,[104',
#   'relation': 'member of',
#   'tail': 'Association for Tourism and Leisure Education'},
#  {'head': 'light', 'relation': 'opposite of', 'tail': 'radio waves'},
#  {'head': 'specialists',
#   'relation': 'field of this occupation',
#   'tail': 'treated'},
#  {'head': 'Street signs', 'relation': 'part of', 'tail': 'block'},
#  {'head': 'Deng Xiaoping', 'relation': 'conflict', 'tail': 'protests'},
#  {'head': 'Battery Place',
#   'relation': 'owned by',
#   'tail': 'New York City Board of Transportation'},
#  {'head': 'Whitson Gordon', 'relation': 'employer', 'tail': 'How-To Geek'},
#  {'head': 'S-line',
#   'relation': 'subclass of',
#   'tail': 'at-grade road crossings'},
#  {'head': 'New York State',
#   'relation': 'contains administrative territorial entity',
#   'tail': 'rural'},
#  {'head': 'New Musical Express',
#   'relation': 'country of origin',
#   'tail': 'British'},
#  {'head': 'Fraser Crossing Partners',
#   'relation': 'parent organization',
#   'tail': 'Aecon Group'},
#  {'head': 'Puhinui Station interchange',
#   'relation': 'date of official opening',
#   'tail': '24 July 2021'},
#  {'head': 'A259', 'relation': 'connects with', 'tail': 'A27'},
#  {'head': 'Jaws (film)', 'relation': 'instance of', 'tail': 'film'},
#  {'head': 'Remote ID',
#   'relation': 'publication date',
#   'tail': 'December 2020'},
#  {'head': 'six-star', 'relation': 'instance of', 'tail': 'energy rating'},
#  {'head': 'snapping turtles', 'relation': 'parent taxon', 'tail': 'turtle'},
#  {'head': 'conned', 'relation': 'practiced by', 'tail': 'con man'},
#  {'head': 'chemistry', 'relation': 'studies', 'tail': 'element'},
#  {'head': 'Mayor', 'relation': 'different from', 'tail': 'Deputy Mayor'},
#  {'head': 'cow', 'relation': 'subclass of', 'tail': 'Animals'},
#  {'head': 'Wrad (talk)',
#   'relation': 'publication date',
#   'tail': '1 November 2008'},
#  {'head': 'South Bay',
#   'relation': 'shares border with',
#   'tail': 'St Nicholas Cliff'},
#  {'head': 'endurance', 'relation': 'subclass of', 'tail': 'races'},
#  {'head': 'DrKiernan (talk)',
#   'relation': 'publication date',
#   'tail': '21 March 2011'},
#  {'head': 'kangeroo', 'relation': 'instance of', 'tail': 'Australian sign'},
#  {'head': 'BadPlayer91', 'relation': 'member of', 'tail': 'contribs'},
#  {'head': "Catherine de' Medici",
#   'relation': 'sibling',
#   'tail': 'Catherine of Aragon'},
#  {'head': 'quoted', 'relation': 'different from', 'tail': 'quoted'},
#  {'head': 'Leicester',
#   'relation': 'twinned administrative body',
#   'tail': 'Nottingham'},
#  {'head': 'carhop', 'relation': 'subclass of', 'tail': 'server'},
#  {'head': 'Megabus', 'relation': 'instance of', 'tail': 'Intercity coach'},
#  {'head': 'GFDL', 'relation': 'derivative work', 'tail': 'CC-SA'},
#  {'head': 'illegal wars', 'relation': 'part of', 'tail': 'international law'},
#  {'head': 'Long Island Expressway',
#   'relation': 'connects with',
#   'tail': 'Whitestone'},
#  {'head': 'streetcar route', 'relation': 'replaced by', 'tail': 'bus'},
#  {'head': 'Ion rapid transit',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Region of Waterloo'},
#  {'head': 'Boeing Field',
#   'relation': 'instance of',
#   'tail': 'industrial area'},
#  {'head': 'incomplete sentence',
#   'relation': 'has part',
#   'tail': 'punctuation'},
#  {'head': 'Block C', 'relation': 'shares border with', 'tail': 'Block F'},
#  {'head': 'Winchester Westgate',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'City of Winchester'},
#  {'head': 'DukesDon',
#   'relation': 'has part',
#   'tail': 'DiabloGoldfishStuart WilkinsonTransformer'},
#  {'head': 'Jahmalm', 'relation': 'significant event', 'tail': '38-hour ban'},
#  {'head': 'Get Off At Edge Hill.[31',
#   'relation': 'performer',
#   'tail': 'Al and Al'},
#  {'head': 'English Nature',
#   'relation': 'replaced by',
#   'tail': 'Natural England'},
#  {'head': 'Parenthetical number',
#   'relation': 'facet of',
#   'tail': 'mass shootings'},
#  {'head': 'noise', 'relation': 'has cause', 'tail': 'construction dust'},
#  {'head': 'Federation', 'relation': 'industry', 'tail': 'tourism'},
#  {'head': 'Lebanon', 'relation': 'diplomatic relation', 'tail': 'Morocco'},
#  {'head': 'Kshitijbansal',
#   'relation': 'date of death',
#   'tail': '6 December 2006'},
#  {'head': '16 inch alloy wheels,[86',
#   'relation': 'followed by',
#   'tail': '17 inch wheels'},
#  {'head': 'train station',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Cincinnati'},
#  {'head': 'Premium', 'relation': 'instance of', 'tail': 'packages'},
#  {'head': 'opening ceremonies of the 2022 Commonwealth Games',
#   'relation': 'part of',
#   'tail': '2022 Commonwealth Games'},
#  {'head': 'connecting pipe',
#   'relation': 'product or material produced',
#   'tail': 'steam'},
#  {'head': '7th Street/6th',
#   'relation': 'connects with',
#   'tail': 'Liberty Avenue'},
#  {'head': 'licence', 'relation': 'sport', 'tail': 'fishing'},
#  {'head': 'Frontier',
#   'relation': 'instance of',
#   'tail': 'Scheduled air service'},
#  {'head': 'guardrail', 'relation': 'different from', 'tail': 'handrail'},
#  {'head': 'Van Gogh museum',
#   'relation': 'has part',
#   'tail': 'Stedelijk Museum'},
#  {'head': 'shields', 'relation': 'part of', 'tail': 'coat of arms'},
#  {'head': 'put in place for a reason',
#   'relation': 'said to be the same as',
#   'tail': 'evolutionary'},
#  {'head': 'district heating',
#   'relation': 'has part',
#   'tail': 'deck level access'},
#  {'head': 'the Plunge',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Santa Cruz'},
#  {'head': 'Canadian Army',
#   'relation': 'has part',
#   'tail': 'The Royal Canadian Regiment'},
#  {'head': 'Overcooked', 'relation': 'platform', 'tail': 'PlayStation 5'},
#  {'head': 'Exporting', 'relation': 'practiced by', 'tail': 'intermediaries'},
#  {'head': "Sherman's advance to Atlanta",
#   'relation': 'participant',
#   'tail': 'Union soldiers'},
#  {'head': 'Johannes Kepler', 'relation': 'occupation', 'tail': 'astronomer'},
#  {'head': 'SoCal Gas',
#   'relation': 'parent organization',
#   'tail': 'SoCal Edison'},
#  {'head': 'bus interchange', 'relation': 'has part', 'tail': 'drop off area'},
#  {'head': 'Marengo (horse)',
#   'relation': 'said to be the same as',
#   'tail': 'Marduk'},
#  {'head': 'Italian opera',
#   'relation': 'country',
#   'tail': 'Polish–Lithuanian Commonwealth.[46'},
#  {'head': 'Water Street',
#   'relation': 'connects with',
#   'tail': 'The Water Street'},
#  {'head': 'Ponte Dom Luís I',
#   'relation': 'replaces',
#   'tail': 'Ponte Pênsil.[40'},
#  {'head': 'Vereeniging',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Gauteng'},
#  {'head': 'sixth', 'relation': 'followed by', 'tail': 'ninth floors'},
#  {'head': 'EBSF',
#   'relation': 'located in the administrative territorial entity',
#   'tail': "nation's capital.[36"},
#  {'head': 'companies', 'relation': 'has part', 'tail': 'departments'},
#  {'head': "Kyleigh's Law",
#   'relation': 'applies to jurisdiction',
#   'tail': 'New Jersey'},
#  {'head': 'shootings',
#   'relation': 'has parts of the class',
#   'tail': 'stabbings'},
#  {'head': 'National Highway System,[3',
#   'relation': 'maintained by',
#   'tail': 'Federal Highway Administration.[4'},
#  {'head': 'monument', 'relation': 'creator', 'tail': 'James Power'},
#  {'head': 'rapid transit station', 'relation': 'owned by', 'tail': 'CTA'},
#  {'head': 'running water',
#   'relation': 'different from',
#   'tail': 'indoor plumbing'},
#  {'head': 'combined system', 'relation': 'length', 'tail': '118'},
#  {'head': 'religious', 'relation': 'has part', 'tail': 'ulema'},
#  {'head': 'change cards',
#   'relation': 'subclass of',
#   'tail': 'magnetic striped tickets'},
#  {'head': 'Of Monsters and Men',
#   'relation': 'location',
#   'tail': 'Hard Rock Colosseum'},
#  {'head': '--Noleander (talk)',
#   'relation': 'publication date',
#   'tail': '11 June 2012'},
#  {'head': 'the Smiths', 'relation': 'has part', 'tail': 'Morrissey'},
#  {'head': 'Théorie des opérations linéaires',
#   'relation': 'composer',
#   'tail': 'Stefan Banachs'},
#  {'head': 'Jennie Lovell-Smith;[92',
#   'relation': 'spouse',
#   'tail': 'William Sidney Lovell-Smith'},
#  {'head': 'Avatar', 'relation': 'uses', 'tail': 'Dolby 3D'},
#  {'head': 'Love Interruption',
#   'relation': 'publication date',
#   'tail': 'January 30, 2012'},
#  {'head': 'Greglocock (talk)',
#   'relation': 'publication date',
#   'tail': '12 December 2008'},
#  {'head': 'Tokyo metropolitan government',
#   'relation': 'has part',
#   'tail': 'special wards'},
#  {'head': 'mayor of Allentown',
#   'relation': 'applies to jurisdiction',
#   'tail': 'Allentown'},
#  {'head': 'Presto', 'relation': 'instance of', 'tail': 'Metropass'},
#  {'head': 'Park blocks',
#   'relation': 'different from',
#   'tail': 'Tom McCall Waterfront Park.[49][54][55'},
#  {'head': 'Seward',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Minneapolis'},
#  {'head': 'Lakeshore West line',
#   'relation': 'connects with',
#   'tail': 'Kitchener line'},
#  {'head': 'passport', 'relation': 'different from', 'tail': 'ticket'},
#  {'head': 'the door', 'relation': 'occupant', 'tail': 'Takeo'},
#  {'head': 'Ved Sharma', 'relation': 'has part', 'tail': 'Ajay-Atul'},
#  {'head': 'partisan rule', 'relation': 'subclass of', 'tail': 'corruption'},
#  {'head': 'anachronism',
#   'relation': 'said to be the same as',
#   'tail': 'noxious'},
#  {'head': 'Hindmarsh Interchange',
#   'relation': 'connects with',
#   'tail': 'Modbury Freeway'},
#  {'head': 'race riot', 'relation': 'location', 'tail': 'New Orleans'},
#  {'head': '3rd Street', 'relation': 'connects with', 'tail': '4th Street.[48'},
#  {'head': 'Bocage Cenomani', 'relation': 'inception', 'tail': '2002'},
#  {'head': "St. Mary's",
#   'relation': 'located on street',
#   'tail': 'Upper Street'},
# ...
#   'tail': 'First Lady'},
#  {'head': 'links', 'relation': 'used by', 'tail': 'wireless'},
#  {'head': 'KUTX.[9',
#   'relation': 'headquarters location',
#   'tail': 'Dealey Center'},
#  {'head': 'legal battle',
#   'relation': 'has part',
#   'tail': 'congressional action'},
#  {'head': 'Konieczny aka Prokonsul Piotrus|',
#   'relation': 'subject has role',
#   'tail': 'Talk'},
#  {'head': 'Clark', 'relation': 'shares border with', 'tail': 'Irving Park'},
#  {'head': 'Muhammad Ali',
#   'relation': 'participant in',
#   'tail': 'Rumble in the Jungle'},
#  {'head': 'John C. Benedict', 'relation': 'father', 'tail': 'my father'},
#  {'head': 'Buddhas', 'relation': 'part of', 'tail': 'Buddhist cosmology'},
#  {'head': 'Piccadilly', 'relation': 'connects with', 'tail': 'Regent-street'},
#  {'head': 'the detainment of children by the U.S. government',
#   'relation': 'said to be the same as',
#   'tail': 'Nazi concentration camps.[9][10'},
#  {'head': '2023 Special Olympics World Summer Games',
#   'relation': 'point in time',
#   'tail': '2023'},
#  {'head': 'Alter és Kiss', 'relation': 'inception', 'tail': '1829'},
#  {'head': 'Omar', 'relation': 'sibling', 'tail': 'Teman'},
#  {'head': 'mitigate climate change',
#   'relation': 'different from',
#   'tail': 'adaptation'},
#  {'head': 'SR-58 shield', 'relation': 'instance of', 'tail': 'dual shield'},
#  {'head': 'taxi stand', 'relation': 'subclass of', 'tail': 'lobbies'},
#  {'head': 'One Dallas Center',
#   'relation': 'architect',
#   'tail': 'Henry N. Cobb'},
#  {'head': 'bus lanes', 'relation': 'subclass of', 'tail': 'bus stops'},
#  {'head': 'Locomotive Act 1865',
#   'relation': 'publication date',
#   'tail': '1865'},
#  {'head': 'Marfa lights',
#   'relation': 'instance of',
#   'tail': "Wills-o'-the-wisp"},
#  {'head': 'historic administrative buildings',
#   'relation': 'has part',
#   'tail': 'restored'},
#  {'head': 'FIGG', 'relation': 'uses', 'tail': 'Peer review'},
#  {'head': 'Rowlett',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Corby'},
#  {'head': 'Waco Suspension Bridge',
#   'relation': 'crosses',
#   'tail': 'Brazos River'},
#  {'head': 'Saltford', 'relation': 'elevation above sea level', 'tail': '1.41'},
#  {'head': 'David Kroyanker',
#   'relation': 'field of work',
#   'tail': 'architectural historian'},
#  {'head': 'Mackay',
#   'relation': 'heritage designation',
#   'tail': 'heritage-listed sites'},
#  {'head': 'Buenos Aires',
#   'relation': 'twinned administrative body',
#   'tail': 'Madrid'},
#  {'head': 'rapid growth of the railways',
#   'relation': 'replaces',
#   'tail': 'original station'},
#  {'head': 'Having a car', 'relation': 'has effect', 'tail': 'desirable'},
#  {'head': 'iPhone 13 mini',
#   'relation': 'followed by',
#   'tail': 'iPhone 13 Pro Max'},
#  {'head': 'Post Office',
#   'relation': 'located on street',
#   'tail': 'Passage of the Post'},
#  {'head': 'responses in line', 'relation': 'facet of', 'tail': 'my responses'},
#  {'head': 'Avoid instruction creep principle',
#   'relation': 'published in',
#   'tail': 'Wikipedia'},
#  {'head': 'Belgium',
#   'relation': 'contains administrative territorial entity',
#   'tail': 'Walloon'},
#  {'head': 'free to play', 'relation': 'opposite of', 'tail': 'ad'},
#  {'head': 'University of the West',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'England.[1'},
#  {'head': 'devices.[267', 'relation': 'part of', 'tail': 'IoT'},
#  {'head': 'countout', 'relation': 'different from', 'tail': 'Championship'},
#  {'head': 'witch trials', 'relation': 'instance of', 'tail': 'subject'},
#  {'head': 'track-and-field', 'relation': 'uses', 'tail': 'facilities'},
#  {'head': 'D-Routes',
#   'relation': 'instance of',
#   'tail': 'national bike routes'},
#  {'head': 'Stambul',
#   'relation': 'located in or next to body of water',
#   'tail': 'Golden Horn'},
#  {'head': 'tower in the park',
#   'relation': 'architect',
#   'tail': 'Le Corbusier'},
#  {'head': 'bicycles', 'relation': 'used by', 'tail': 'naked men on bicycles'},
#  {'head': 'Klas Tham', 'relation': 'occupation', 'tail': 'Head architect'},
#  {'head': 'startups',
#   'relation': 'subclass of',
#   'tail': 'established companies'},
#  {'head': 'Shimogamo Shrine',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Kyoto'},
#  {'head': 'Bill & Melinda Gates Foundation Headquarters',
#   'relation': 'part of',
#   'tail': 'Russell Investments Center'},
#  {'head': 'bubble tea', 'relation': 'subclass of', 'tail': 'milk tea'},
#  {'head': 'Daniel Ruth', 'relation': 'employer', 'tail': 'Chicago Sun-Times'},
#  {'head': 'vineyards', 'relation': 'subclass of', 'tail': 'agricultural land'},
#  {'head': 'Casa Bruja Microbrewery',
#   'relation': 'product or material produced',
#   'tail': 'beers'},
#  {'head': 'petrols', 'relation': 'opposite of', 'tail': 'diesels'},
#  {'head': 'populated form classes',
#   'relation': 'number of participants',
#   'tail': '28'},
#  {'head': '1936', 'relation': 'point in time', 'tail': 'January 1936'},
#  {'head': 'Hunter', 'relation': 'sibling', 'tail': 'Ashley.[140'},
#  {'head': 'his family', 'relation': 'has part', 'tail': 'Bertha'},
#  {'head': 'Norseman.[7', 'relation': 'instance of', 'tail': 'gimmick'},
#  {'head': 'NYC Parks',
#   'relation': 'parent organization',
#   'tail': 'Parks Department'},
#  {'head': 'alternative accentuation type',
#   'relation': 'subclass of',
#   'tail': 'accentuation'},
#  {'head': 'Ocean Dumping Act', 'relation': 'country', 'tail': 'United States'},
#  {'head': 'Roxy', 'relation': 'owner of', 'tail': 'Radio City'},
#  {'head': 'Ford Foundation Building',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Turtle Bay'},
#  {'head': 'diners.[4', 'relation': 'uses', 'tail': 'round tables'},
#  {'head': 'self-sacrifice',
#   'relation': 'said to be the same as',
#   'tail': 'pelican'},
#  {'head': 'hide the problem', 'relation': 'subclass of', 'tail': 'problem'},
#  {'head': 'East Coast Main Line',
#   'relation': 'terminus',
#   'tail': "King's Cross"},
#  {'head': 'toque flamenco', 'relation': 'facet of', 'tail': 'Flamenco'},
#  {'head': 'training sets', 'relation': 'part of', 'tail': 'learning theory'},
#  {'head': "Magti's", 'relation': 'product or material produced', 'tail': '4G'},
#  {'head': 'Seventh Avenue South',
#   'relation': 'connects with',
#   'tail': 'Greenwich Avenue'},
#  {'head': 'Disney Signature Experiences',
#   'relation': 'chairperson',
#   'tail': 'Jeff Vahle'},
#  {'head': 'courtyards', 'relation': 'subclass of', 'tail': 'courtyards'},
#  {'head': 'AirTrain JFK',
#   'relation': 'instance of',
#   'tail': 'platform screen doors'},
#  {'head': 'professional program',
#   'relation': 'number of participants',
#   'tail': '14'},
#  {'head': 'deliberately cut in half',
#   'relation': 'facet of',
#   'tail': 'seahorse statue'},
#  {'head': 'Douglas Carswell',
#   'relation': 'member of political party',
#   'tail': 'UK Independence Party'},
#  {'head': 'Gerald Patterson',
#   'relation': 'country of citizenship',
#   'tail': 'Australia'},
#  {'head': 'publication ban', 'relation': 'facet of', 'tail': 'public'},
#  {'head': 'horse', 'relation': 'use', 'tail': 'transportation'},
#  {'head': 'Buíça',
#   'relation': 'educated at',
#   'tail': 'master-at-arms training course'},
#  {'head': 'MAN TGL Series', 'relation': 'manufacturer', 'tail': 'MAN'},
#  {'head': 'lower-income individuals',
#   'relation': 'opposite of',
#   'tail': 'higher-income families'},
#  {'head': 'Manzana de la Rivera', 'relation': 'instance of', 'tail': 'museum'},
#  {'head': '2', 'relation': 'different from', 'tail': "don't they?"},
#  {'head': 'rent-a-cops', 'relation': 'subclass of', 'tail': 'police'},
#  {'head': 'Hawker', 'relation': 'subclass of', 'tail': 'stalls'},
#  {'head': 'Chinese New Year',
#   'relation': 'language of work or name',
#   'tail': 'Cantonese dialect'},
#  {'head': 'Baltimore dialect',
#   'relation': 'indigenous to',
#   'tail': 'Baltimore'},
#  {'head': 'Belváros district',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Pest'},
#  {'head': 'Cygnus (constellation)',
#   'relation': 'has part',
#   'tail': 'Cyd Charisse'},
#  {'head': 'Deathly Hallows',
#   'relation': 'genre',
#   'tail': 'third person limited point of view'},
#  {'head': 'handrail', 'relation': 'part of', 'tail': 'stairs'},
#  {'head': 'anode', 'relation': 'part of', 'tail': 'fuel cell'},
#  {'head': 'Hudson', 'relation': 'mouth of the watercourse', 'tail': 'ocean'},
#  {'head': 'technical provisions', 'relation': 'part of', 'tail': 'Title V'},
#  {'head': 'Iñaki Azkuna',
#   'relation': 'award received',
#   'tail': 'World Mayor Prize'},
#  {'head': 'long-distance buses', 'relation': 'country', 'tail': 'Thailand'},
#  {'head': 'Model 3.[66', 'relation': 'follows', 'tail': 'Model Y,[65'},
#  {'head': 'B4 designs',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Kentucky'},
#  {'head': 'Philippines', 'relation': 'instance of', 'tail': 'households'},
#  {'head': 'Polmar', 'relation': 'different from', 'tail': 'Nordeen'},
#  {'head': 'Sheridan', 'relation': 'shares border with', 'tail': 'Buffalo'},
#  {'head': 'Shazia', 'relation': 'present in work', 'tail': 'episode'},
#  {'head': 'Iraqi National Assembly', 'relation': 'country', 'tail': 'Iraq'},
#  {'head': 'third game', 'relation': 'follows', 'tail': 'first two games'},
#  {'head': 'Jinyu Hutong station',
#   'relation': 'connecting line',
#   'tail': 'Line 8'},
#  {'head': 'Back Bay', 'relation': 'owned by', 'tail': 'Amtrak'},
#  {'head': 'Madison Street Bridge No. 2',
#   'relation': 'follows',
#   'tail': 'Madison Street Bridge No. 1'},
#  {'head': 'dam', 'relation': 'use', 'tail': 'watered'},
#  {'head': 'Leatherhead',
#   'relation': 'connecting line',
#   'tail': 'Chessington Branch Line'},
#  {'head': 'harmless fatwas', 'relation': 'subclass of', 'tail': 'fatwa'},
#  {'head': 'J&P-Avax', 'relation': 'country', 'tail': 'French'},
#  {'head': 'Valley Mountain Bikers Association',
#   'relation': 'sport',
#   'tail': 'mountain biking'},
#  {'head': 'alderman', 'relation': 'part of', 'tail': 'Rockford City Council'},
#  {'head': 'Selby', 'relation': 'connects with', 'tail': 'Snelling'},
#  {'head': 'Warthill',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'North Yorkshire'},
#  {'head': 'United States of America',
#   'relation': 'diplomatic relation',
#   'tail': 'United Kingdom of Great Britain and Northern Ireland'},
#  {'head': 'nuclear power', 'relation': 'different from', 'tail': 'unsafe'},
#  {'head': 'concrete barriers',
#   'relation': 'part of',
#   'tail': 'New security measures'},
#  {'head': 'engineering', 'relation': 'studies', 'tail': 'climate'},
#  {'head': 'Wake Up, KHS in 4',
#   'relation': 'characters',
#   'tail': 'Mr. Bananaman'},
#  {'head': 'Spain', 'relation': 'shares border with', 'tail': 'Germany'},
#  {'head': 'http://en.wikipedia.org/wiki/Harrington_Road_tram_stop',
#   'relation': 'located on street',
#   'tail': 'Harrington Road'},
#  {'head': 'Districts', 'relation': 'part of', 'tail': 'set'},
#  {'head': 'clays', 'relation': 'subclass of', 'tail': 'alluvial soils'},
#  {'head': '30 Super', 'relation': 'part of the series', 'tail': 'Super'},
#  {'head': 'Wooroloo', 'relation': 'shares border with', 'tail': 'Clackline'},
#  {'head': 'Rajeev', 'relation': 'father', 'tail': 'Barry'},
#  {'head': 'Harry Brown',
#   'relation': 'publication date',
#   'tail': '11 November 2009'},
#  {'head': 'axes', 'relation': 'part of', 'tail': 'tombs'},
#  {'head': 'Kingman Island.[91',
#   'relation': 'instance of',
#   'tail': 'wildlife refuge'},
#  {'head': 'Cheshire', 'relation': 'shares border with', 'tail': 'Leeds'},
#  {'head': 'Fifth Avenue',
#   'relation': 'connects with',
#   'tail': 'Washington Square South'},
#  {'head': 'LNWR', 'relation': 'replaces', 'tail': 'North London Railway'},
#  {'head': 'Ross Park',
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Seattle'},
#  {'head': 'express platforms', 'relation': 'part of', 'tail': 'IRT'},
#  {'head': "Brisbane's universities",
#   'relation': 'located in the administrative territorial entity',
#   'tail': 'Brisbane'},
#  {'head': 'Jurong East MRT station',
#   'relation': 'operator',
#   'tail': 'SMRT Trains'},
#  {'head': 'Herz Playground', 'relation': 'inception', 'tail': '1965.[3'},
#  {'head': 'off-the-grid', 'relation': 'different from', 'tail': 'grid'},
#  {'head': 'Zanco', 'relation': 'owner of', 'tail': "Magid's"},
#  {'head': 'stir-fry', 'relation': 'has part', 'tail': 'mushrooms'},
#  {'head': 'public speaking', 'relation': 'instance of', 'tail': 'skills'},
#  {'head': 'French Embassy, Moscow', 'relation': 'country', 'tail': 'Russia'},
#  {'head': 'identity', 'relation': 'has part', 'tail': 'Gender'},
#  {'head': 'Streetsville',
#   'relation': 'shares border with',
#   'tail': 'Port Credit'},
#  {'head': 'CTrain', 'relation': 'has part', 'tail': 'Red Line'},
#  {'head': 'Charleston',
#   'relation': 'elevation above sea level',
#   'tail': '18th'},
#  {'head': 'wheelchair-accessible',
#   'relation': 'different from',
#   'tail': 'pedestrian subway'},
#  {'head': 'Embarcadero Freeway', 'relation': 'instance of', 'tail': 'Freeway'},
#  {'head': 'Nied railway bridge', 'relation': 'inception', 'tail': '1839'},
#  {'head': 'Mayor', 'relation': 'officeholder', 'tail': 'Koch'},
#  {'head': 'B class', 'relation': 'said to be the same as', 'tail': 'GA'},
#  {'head': 'New Jersey Turnpike', 'relation': 'maintained by', 'tail': 'NJDOT'},
#  {'head': 'SLG(R)', 'relation': 'instance of', 'tail': 'reducing'},
#  {'head': 'array', 'relation': 'subclass of', 'tail': 'data structure'},
#  {'head': 'but one', 'relation': 'has part', 'tail': 'but'},
#  {'head': 'Hong Kong Island',
#   'relation': 'shares border with',
#   'tail': 'New Territories'},
#  {'head': 'Redondo Beach via Playa del Rey Line',
#   'relation': 'instance of',
#   'tail': 'rail trail'},
#  {'head': 'failed expeditions',
#   'relation': 'facet of',
#   'tail': 'Islamise the region'},
#  {'head': 'hybrid electric vehicles',
#   'relation': 'subclass of',
#   'tail': 'quiet electric'},
#  {'head': 'Vasiliy Mitrokhin', 'relation': 'employer', 'tail': 'KGB'},
#  {'head': 'Deptford Dockyard.[7',
#   'relation': 'owned by',
#   'tail': 'Peter Pett'},
#  {'head': 'Glenelg River',
#   'relation': 'mouth of the watercourse',
#   'tail': 'Glenelg Hopkins'},
#  {'head': 'David Sterrit', 'relation': 'spouse', 'tail': 'Lucille Rhodes'},
#  {'head': 'the final script',
#   'relation': 'characters',
#   'tail': 'half to her relief'},
#  {'head': 'DrKiernan',
#   'relation': 'date of death',
#   'tail': '12 November 2007'},
#  {'head': 'junior high', 'relation': 'subclass of', 'tail': 'High School'},
#  {'head': 'US 9W', 'relation': 'connects with', 'tail': 'NY 385'},
#  {'head': 'Montgomery', 'relation': 'part of', 'tail': 'sister city'},
#  {'head': 'Oralit',
#   'relation': 'product or material produced',
#   'tail': 'rehydration salts'},
#  {'head': 'Villa Park Dam',
#   'relation': 'located on terrain feature',
#   'tail': 'Irvine Lake'},
#  {'head': 'Three Girls', 'relation': 'has part', 'tail': 'Three'},
#  {'head': 'John Root', 'relation': 'notable work', 'tail': 'Chicago skyline'},
#  {'head': 'San Marco',
#   'relation': 'shares border with',
#   'tail': 'South Jacksonville'},
#  {'head': 'bus hubs', 'relation': 'different from', 'tail': 'hubs'},
#  {'head': 'sitins', 'relation': 'subclass of', 'tail': 'protests'},
#  {'head': 'The Man Without a Body',
#   'relation': 'director',
#   'tail': 'Charles Saunders'},
#  {'head': 'Lê Thị Thúy', 'relation': 'instance of', 'tail': 'middle name'},
#  {'head': 'Palace nightclub', 'relation': 'inception', 'tail': '1971'},
#  {'head': 'Facebook', 'relation': 'instance of', 'tail': 'social-media'},
#  {'head': 'Continental Limited', 'relation': 'country', 'tail': 'Canada'},
#  {'head': 'neon lighting', 'relation': 'part of', 'tail': 'cinema'},
#  {'head': 'Elsa', 'relation': 'sibling', 'tail': 'Helen'},
#  {'head': 'Driehaus Prize',
#   'relation': 'winner',
#   'tail': 'Elizabeth Plater-Zyberk'},
#  {'head': 'Kröller-Müller Museum', 'relation': 'location', 'tail': 'Otterlo'},
#  {'head': 'Acute respiratory disease of recruits',
#   'relation': 'has cause',
#   'tail': 'adenovirus'},
#  {'head': 'East Coast/West Coast World Series',
#   'relation': 'has part',
#   'tail': '1977'},
#  {'head': 'Zebra crossings', 'relation': 'different from', 'tail': 'beacons'},
#  ...]

# %%
with open("kb_ped_wiki_all.json", "w") as json_file:
    json.dump(unique_combined_list, json_file)
